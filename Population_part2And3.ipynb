# %%
import pandas as pd
import numpy as np
import re
import pyodbc

# %%
file_name = "./data/Population 2021.xlsx"

# %%
xl = pd.ExcelFile(file_name)
for sheet in xl.sheet_names:
    print(sheet)
# Out:
# 索引 Index
# E101e
# E102e
# E103e
# E104e
# E105e
# E106ae
# E106be
# E106ce
# E107ae
# E107be
# E108ae
# E108be
# E109e
# E110e
# E111ae
# E111be
# E111ce
# E111de
# E112e
# E113e
# E114e
# E115e
# E116e
# E117e
# E118ae
# E118be
# E119e
# E201ae
# E201be
# E201ce
# E201de
# E201ee
# E202e
# E203e
# E204e
# E205e
# E206e
# E207e
# E208e
# E209e
# E210e
# E301e
# E302e
# E303e
# E304e
# E305e
# E401e

# %%
df1a = xl.parse("E201ae")

# %%
df1a = df1a.iloc[1:26,:-2]

# %%
df1a = df1a.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\3576524069.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1a = df1a.fillna(method="ffill")

# %%
result_df = pd.DataFrame()

# %%
for idx in range(4,25):
    new_row = [2021, df1a.iloc[idx,0], re.sub(r'\([^)]*\)', '', df1a.iloc[idx,1]), df1a.iloc[idx,2], "Median monthly household income expressed in HK$"]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "Region", "District", "MedianMonthlyHouseholdIncome", "Description"]

# %%
result_df
# Out:
#     Year            Region             District  MedianMonthlyHouseholdIncome  \
# 0   2021  Hong Kong Island  Central and Western                         45040
# 1   2021  Hong Kong Island            Wan Chai                          45000
# 2   2021  Hong Kong Island             Eastern                          32000
# 3   2021  Hong Kong Island             Southern                         32440
# 4   2021  Hong Kong Island            Sub-Total                         35440
# 5   2021           Kowloon        Yau Tsim Mong                         26080
# 6   2021           Kowloon         Sham Shui Po                         21490
# 7   2021           Kowloon         Kowloon City                         30010
# 8   2021           Kowloon         Wong Tai Sin                         23520
# 9   2021           Kowloon            Kwun Tong                         22000
# 10  2021           Kowloon            Sub-Total                         23860
# ...

# %%
server = "db-at-dev-01.database.windows.net"
database = "db-at-dev-gas-sale-01"
username = "sqladmin"
password = "Password2025"

# %%
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E201ae_HouseholdIncomeByDistrict (Year, Region, District, MedianMonthlyHouseholdIncome, Description) values(?,?,?,?,?)", row.Year, row.Region, row.District, row.MedianMonthlyHouseholdIncome, row.Description) 
cnxn.commit()
cursor.close()

# %%
df1b = xl.parse("E201be")

# %%
df1b = df1b.iloc[1:26,:-2]

# %%
df1b = df1b.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\3732834964.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1b = df1b.fillna(method="ffill")

# %%
result_df = pd.DataFrame()

# %%
for idx in range(4,25):
    new_row = [2021, df1b.iloc[idx,0], re.sub(r'\([^)]*\)', '', df1b.iloc[idx,1]), df1b.iloc[idx,2], "Median monthly rent expressed in HK$"]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "Region", "District", "MedianMonthlyRent", "Description"]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E201be_RentByDistrict (Year, Region, District, MedianMonthlyRent, Description) values(?,?,?,?,?)", row.Year, row.Region, row.District, row.MedianMonthlyRent, row.Description) 
cnxn.commit()
cursor.close()

# %%
df1c = xl.parse("E201ce")

# %%
df1c = df1c.iloc[1:26,:-2]

# %%
df1c = df1c.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\2546411591.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1c = df1c.fillna(method="ffill")

# %%
result_df = pd.DataFrame()

# %%
for idx in range(4,25):
    new_row = [2021, df1c.iloc[idx,0], re.sub(r'\([^)]*\)', '', df1c.iloc[idx,1]), df1c.iloc[idx,2], "Median monthly mortgage payment expressed in HK$"]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "Region", "District", "MedianMonthlyMortgagePayment", "Description"]

# %%
result_df
# Out:
#     Year            Region             District  MedianMonthlyMortgagePayment  \
# 0   2021  Hong Kong Island  Central and Western                         18000
# 1   2021  Hong Kong Island            Wan Chai                          20000
# 2   2021  Hong Kong Island             Eastern                          14000
# 3   2021  Hong Kong Island             Southern                         13750
# 4   2021  Hong Kong Island            Sub-Total                         15000
# 5   2021           Kowloon        Yau Tsim Mong                         13530
# 6   2021           Kowloon         Sham Shui Po                         12500
# 7   2021           Kowloon         Kowloon City                         15000
# 8   2021           Kowloon         Wong Tai Sin                          8500
# 9   2021           Kowloon            Kwun Tong                         11000
# 10  2021           Kowloon            Sub-Total                         12500
# ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E201ce_MortgagePaymentByDistrict (Year, Region, District, MedianMonthlyMortgagePayment, Description) values(?,?,?,?,?)", row.Year, row.Region, row.District, row.MedianMonthlyMortgagePayment, row.Description) 
cnxn.commit()
cursor.close()

# %%
df1d = xl.parse("E201de")

# %%
df1d = df1d.iloc[1:26,:-2]

# %%
df1d = df1d.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\2316214529.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1d = df1d.fillna(method="ffill")

# %%
result_df = pd.DataFrame()

# %%
for idx in range(4,25):
    new_row = [2021, df1d.iloc[idx,0], re.sub(r'\([^)]*\)', '', df1d.iloc[idx,1]), df1d.iloc[idx,2], "Median rent to income ratio expressed in percentage"]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "Region", "District", "MedianRentToIncomeRatio", "Description"]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E201de_RentToIncomeRatioByDistrict (Year, Region, District, MedianRentToIncomeRatio, Description) values(?,?,?,?,?)", row.Year, row.Region, row.District, row.MedianRentToIncomeRatio, row.Description) 
cnxn.commit()
cursor.close()

# %%
df1e = xl.parse("E201ee")

# %%
df1e = df1e.iloc[1:26,:-2]

# %%
df1e = df1e.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\2945011938.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1e = df1e.fillna(method="ffill")

# %%
result_df = pd.DataFrame()

# %%
for idx in range(4,25):
    new_row = [2021, df1e.iloc[idx,0], re.sub(r'\([^)]*\)', '', df1e.iloc[idx,1]), df1e.iloc[idx,2], "Median mortgage payment to income ratio expressed in percentage"]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "Region", "District", "MedianMortgagePaymentToIncomeRatio", "Description"]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E201ee_MortgagePaymentToIncomeRatioByDistrict (Year, Region, District, MedianMortgagePaymentToIncomeRatio, Description) values(?,?,?,?,?)", row.Year, row.Region, row.District, row.MedianMortgagePaymentToIncomeRatio, row.Description) 
cnxn.commit()
cursor.close()

# %%
df3 = xl.parse("E203e")

# %%
df3 = df3.iloc[1:24,:-2]

# %%
df3
# Out:
#    Table E203 : Average Number of Occupants by District Council District, Year and Type of Housing  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4                                     Type of Housing
# 5                           District Council District
# 6                                 Central and Western
# 7                                        Wan Chai (1)
# 8                                         Eastern (1)
# 9                                            Southern
# 10                                      Yau Tsim Mong
# 11                                       Sham Shui Po
# 12                                       Kowloon City
# 13                                       Wong Tai Sin
# 14                                          Kwun Tong
# 15                                         Kwai Tsing
# 16                                          Tsuen Wan
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df3.iloc[3,1:]):
    for inner_idx, district in enumerate(df3.iloc[5:,0]):
        new_row = [2021, housingType, re.sub(r'\([^)]*\)', '', district), df3.iloc[5+inner_idx, 1+idx], "Number of occupants is expressed per 1000 units of quarters"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "District", "AverageNumberOfOccupants", "Description"]

# %%
result_df
# Out:
#      Year            HousingType             District  \
# 0    2021  Public rental housing  Central and Western
# 1    2021  Public rental housing            Wan Chai
# 2    2021  Public rental housing             Eastern
# 3    2021  Public rental housing             Southern
# 4    2021  Public rental housing        Yau Tsim Mong
# ..    ...                    ...                  ...
# 103  2021                Overall                North
# 104  2021                Overall               Tai Po
# 105  2021                Overall              Sha Tin
# 106  2021                Overall             Sai Kung
# 107  2021                Overall              Islands
#
#     AverageNumberOfOccupants  \
# 0                       2858
# 1                       2475
# 2                       2772
# 3                       2762
# 4                       2750
# ..                       ...
# 103                     2765
# 104                     2836
# 105                     2790
# ...

# %%
def toEmptyOrFloat(value):
    if (str(value) == "--"):
        pass
    else:
        return float(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E203e_OccupantByHousingTypeAndDistrict (Year, HousingType, District, AverageNumberOfOccupants, Description) values(?,?,?,?,?)", row.Year, row.HousingType, row.District, toEmptyOrFloat(row.AverageNumberOfOccupants), row.Description) 
cnxn.commit()
cursor.close()

# %%
df4 = xl.parse("E204e")

# %%
df4 = df4.iloc[1:27,:-2]

# %%
df4 = df4.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\4143017505.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4 = df4.fillna(method="ffill")

# %%
df4
# Out:
#    Table E204 : Average Number of Rooms by District Council District, Year and Type of Housing  \
# 1                                                Year
# 2                                     Type of Housing
# 3                                     Type of Housing
# 4                                     Type of Housing
# 5   Region - Hong Kong Island/ Kowloon/ New Territ...
# 6                                    Hong Kong Island
# 7                                    Hong Kong Island
# 8                                    Hong Kong Island
# 9                                    Hong Kong Island
# 10                                   Hong Kong Island
# 11                                            Kowloon
# 12                                            Kowloon
# 13                                            Kowloon
# 14                                            Kowloon
# 15                                            Kowloon
# 16                                            Kowloon
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df4.iloc[1,2:].dropna()):
    for inner_idx, district in enumerate(df4.iloc[5:,1]):
        new_row = [2021, housingType, df4.iloc[5+inner_idx,0], re.sub(r'\([^)]*\)', '', district), df4.iloc[5+inner_idx,idx*2+2], df4.iloc[5+inner_idx,idx*2+3], "Number of rooms includes living/ dining rooms, bedrooms and other rooms, while kitchens and bathrooms/ toilets are excluded."]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "Region", "District", "AverageNumberOfRoomsPerHousehold", "AverageNumberOfRoomsPerPerson", "Description"]

# %%
result_df
# Out:
#      Year            HousingType            Region             District  \
# 0    2021  Public rental housing  Hong Kong Island  Central and Western
# 1    2021  Public rental housing  Hong Kong Island            Wan Chai
# 2    2021  Public rental housing  Hong Kong Island             Eastern
# 3    2021  Public rental housing  Hong Kong Island             Southern
# 4    2021  Public rental housing  Hong Kong Island            Sub-Total
# ..    ...                    ...               ...                  ...
# 121  2021                Overall   New Territories               Tai Po
# 122  2021                Overall   New Territories              Sha Tin
# 123  2021                Overall   New Territories             Sai Kung
# 124  2021                Overall   New Territories              Islands
# 125  2021                Overall   New Territories            Sub-Total
#
#     AverageNumberOfRoomsPerHousehold AverageNumberOfRoomsPerPerson  \
# ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E204e_NumberOfRoomsByHousingTypeAndDistrict (Year, HousingType, Region, District, AverageNumberOfRoomsPerHousehold, AverageNumberOfRoomsPerPerson, Description) values(?,?,?,?,?,?,?)", row.Year, row.HousingType, row.Region, row.District, toEmptyOrFloat(row.AverageNumberOfRoomsPerHousehold), toEmptyOrFloat(row.AverageNumberOfRoomsPerPerson), row.Description) 
cnxn.commit()
cursor.close()

# %%
df5 = xl.parse("E205e")

# %%
df5 = df5.iloc[1:24,:-2]

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df5.iloc[3, 1:]):
    for inner_idx, district in enumerate(df5.iloc[5:,0]):
        new_row = [2021, housingType, re.sub(r'\([^)]*\)', '', district), df5.iloc[5+inner_idx,idx+1], "Median monthly household income expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "District", "MedianMonthlyHouseholdIncome", "Description"]

# %%
result_df
# Out:
#      Year            HousingType             District  \
# 0    2021  Public rental housing  Central and Western
# 1    2021  Public rental housing            Wan Chai
# 2    2021  Public rental housing             Eastern
# 3    2021  Public rental housing             Southern
# 4    2021  Public rental housing        Yau Tsim Mong
# ..    ...                    ...                  ...
# 103  2021                Overall                North
# 104  2021                Overall               Tai Po
# 105  2021                Overall              Sha Tin
# 106  2021                Overall             Sai Kung
# 107  2021                Overall              Islands
#
#     MedianMonthlyHouseholdIncome  \
# 0                          25170
# 1                          16000
# 2                          20040
# 3                          20320
# 4                          20040
# ..                           ...
# 103                        23580
# 104                        30000
# ...

# %%
def toEmptyOrInt(value):
    if (str(value) == "--"):
        pass
    else:
        return int(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E205e_HouseholdIncomeByHousingTypeAndDistrict (Year, HousingType, District, MedianMonthlyHouseholdIncome, Description) values(?,?,?,?,?)", row.Year, row.HousingType, row.District, toEmptyOrInt(row.MedianMonthlyHouseholdIncome), row.Description) 
cnxn.commit()
cursor.close()

# %%
df6 = xl.parse("E206e")

# %%
df6 = df6.iloc[1:27,:-2]

# %%
df6 = df6.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\1399719919.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df6 = df6.fillna(method="ffill")

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df6.iloc[3, 2:]):
    for inner_idx, district in enumerate(df6.iloc[5:,1]):
        new_row = [2021, housingType, df6.iloc[5+inner_idx, idx], re.sub(r'\([^)]*\)', '', district), df6.iloc[5+inner_idx, idx+2], "Median monthly rent expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "Region", "District", "MedianMonthlyRent", "Description"]

# %%
result_df
# Out:
#      Year                  HousingType            Region             District  \
# 0    2021  Public rental housing units  Hong Kong Island  Central and Western
# 1    2021  Public rental housing units  Hong Kong Island            Wan Chai
# 2    2021  Public rental housing units  Hong Kong Island             Eastern
# 3    2021  Public rental housing units  Hong Kong Island             Southern
# 4    2021  Public rental housing units  Hong Kong Island            Sub-Total
# ..    ...                          ...               ...                  ...
# 121  2021                      Overall              4000               Tai Po
# 122  2021                      Overall             12000              Sha Tin
# 123  2021                      Overall              9000             Sai Kung
# 124  2021                      Overall              8000              Islands
# 125  2021                      Overall              5700            Sub-Total
#
# ...

# %%
def toEmptyOrInt(value):
    if (str(value) == "***"):
        pass
    else:
        return int(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E206e_RentByHousingTypeAndDistrict (Year, HousingType, Region, District, MedianMonthlyRent, Description) values(?,?,?,?,?,?)", row.Year, row.HousingType, row.Region, row.District, toEmptyOrInt(row.MedianMonthlyRent), row.Description) 
cnxn.commit()
cursor.close()

# %%
df7 = xl.parse("E207e")

# %%
df7 = df7.iloc[1:24,:-2]

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df7.iloc[3,1:]):
    for inner_idx, district in enumerate(df7.iloc[5:,0]):
        new_row = [2021, housingType, re.sub(r'\([^)]*\)', '', district), df7.iloc[5+inner_idx, idx+1], "Median rent to income ratio expressed in percentage"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "District", "MedianRentToIncomeRatio", "Description"]

# %%
result_df
# Out:
#      Year                  HousingType             District  \
# 0    2021  Public rental housing units  Central and Western
# 1    2021  Public rental housing units            Wan Chai
# 2    2021  Public rental housing units             Eastern
# 3    2021  Public rental housing units             Southern
# 4    2021  Public rental housing units        Yau Tsim Mong
# ..    ...                          ...                  ...
# 103  2021                      Overall                North
# 104  2021                      Overall               Tai Po
# 105  2021                      Overall              Sha Tin
# 106  2021                      Overall             Sai Kung
# 107  2021                      Overall              Islands
#
#     MedianRentToIncomeRatio                                        Description
# 0                       9.8  Median rent to income ratio expressed in perce...
# 1                      11.0  Median rent to income ratio expressed in perce...
# ...

# %%
def toEmptyOrFloat(value):
    if (str(value) == "***"):
        pass
    else:
        return float(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E207e_RentToIncomeRatioByHousingTypeAndDistrict (Year, HousingType, District, MedianRentToIncomeRatio, Description) values(?,?,?,?,?)", row.Year, row.HousingType, row.District, toEmptyOrFloat(row.MedianRentToIncomeRatio), row.Description) 
cnxn.commit()
cursor.close()

# %%
df8 = xl.parse("E208e")

# %%
df8 = df8.iloc[1:26,:-2]

# %%
df8.fillna(method="ffill", inplace=True)
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\2273625320.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df8.fillna(method="ffill", inplace=True)

# %%
df8
# Out:
#    Table E208 : Occupied Quarters by District Council District and Year  \
# 1                                                Year
# 2                                                Year
# 3                                                Year
# 4   Region - Hong Kong Island/ Kowloon/ New Territ...
# 5                                    Hong Kong Island
# 6                                    Hong Kong Island
# 7                                    Hong Kong Island
# 8                                    Hong Kong Island
# 9                                    Hong Kong Island
# 10                                            Kowloon
# 11                                            Kowloon
# 12                                            Kowloon
# 13                                            Kowloon
# 14                                            Kowloon
# 15                                            Kowloon
# 16                                    New Territories
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df8.iloc[0,2:].dropna()):
    for inner_idx, district in enumerate(df8.iloc[4:,1]):
        new_row = [year, df8.iloc[4+inner_idx, 0], re.sub(r'\([^)]*\)', '', district), df8.iloc[4+inner_idx, idx*2 + 2], df8.iloc[4+inner_idx, idx*2 + 3], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "Region", "District", "NumberOfOccupiedQuarters", "PercentageOfOccupiedQuarters", "Description"]

# %%
result_df
# Out:
#     Year            Region             District  NumberOfOccupiedQuarters  \
# 0   2011  Hong Kong Island  Central and Western                     90752
# 1   2011  Hong Kong Island            Wan Chai                      55041
# 2   2011  Hong Kong Island             Eastern                     194791
# 3   2011  Hong Kong Island             Southern                     86599
# 4   2011  Hong Kong Island            Sub-Total                    427183
# ..   ...               ...                  ...                       ...
# 58  2021   New Territories               Tai Po                    111574
# 59  2021   New Territories              Sha Tin                    248315
# 60  2021   New Territories             Sai Kung                    168975
# 61  2021   New Territories              Islands                     67547
# 62  2021   New Territories            Sub-Total                   1423818
#
#     PercentageOfOccupiedQuarters Description
# 0                            3.8
# ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E208e_OccupiedQuarterByDistrictAndYear (Year, Region, District, NumberOfOccupiedQuarters, PercentageOfOccupiedQuarters, Description) values(?,?,?,?,?,?)", row.Year, row.Region, row.District, row.NumberOfOccupiedQuarters, row.PercentageOfOccupiedQuarters, row.Description) 
cnxn.commit()
cursor.close()

# %%
df9 = xl.parse("E209e")

# %%
df9 = df9.iloc[1:276,:-2]

# %%
df9
# Out:
#     Table E209 : Domestic Households by District Council District, Monthly Domestic Household Income (HK$), Year and Type of Housing  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4                                      Type of Housing
# 5                            District Council District
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
#
#                                   Unnamed: 1             Unnamed: 2  \
# 1                                        NaN    Domestic Households
# 2                                        NaN                 Number
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df9.iloc[3,2:]):
    for inner_idx, district in enumerate(df9.iloc[5:,0].dropna()):
        for third_idx, householdIncome in enumerate(df9.iloc[5:20, 1]):
            new_row = [2021, housingType, re.sub(r'\([^)]*\)', '', district), householdIncome, df9.iloc[5+inner_idx*15+third_idx,idx+2], "Month household income expressed in HK$"]
            result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "District", "MonthlyHouseholdIncomeRange", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#       Year            HousingType             District  \
# 0     2021  Public rental housing  Central and Western
# 1     2021  Public rental housing  Central and Western
# 2     2021  Public rental housing  Central and Western
# 3     2021  Public rental housing  Central and Western
# 4     2021  Public rental housing  Central and Western
# ...    ...                    ...                  ...
# 1615  2021                  Total              Islands
# 1616  2021                  Total              Islands
# 1617  2021                  Total              Islands
# 1618  2021                  Total              Islands
# 1619  2021                  Total              Islands
#
#      MonthlyHouseholdIncomeRange NumberOfHouseholds  \
# 0                Less than 2,000                 86
# 1                  2,000 - 3,999                 70
# 2                  4,000 - 5,999                105
# 3                  6,000 - 7,999                276
# ...

# %%
def toEmptyOrInt(value):
    if (str(value) == "--"):
        pass
    else:
        return int(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E209e_HouseholdByHousingTypeAndDistrictAndHouseholdIncome (Year, HousingType, District, MonthlyHouseholdIncomeRange, NumberOfHouseholds, Description) values(?,?,?,?,?,?)", row.Year, row.HousingType, row.District, row.MonthlyHouseholdIncomeRange, toEmptyOrInt(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df10 = xl.parse("E210e")

# %%
df10 = df10.iloc[3:27,:-2]

# %%
df10 = df10.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_36324\1511493510.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df10 = df10.fillna(method="ffill")

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df10.iloc[1,2:]):
    for inner_idx, district in enumerate(df10.iloc[3:,1]):
        new_row = [2021, housingType, df10.iloc[3+inner_idx,0], re.sub(r'\([^)]*\)', '', district), df10.iloc[3+inner_idx,2+idx], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "QuarterType", "Region", "District", "NumberOfOccupiedQuarters", "Description"]

# %%
result_df
# Out:
#      Year                  QuarterType            Region             District  \
# 0    2021  Public rental housing units  Hong Kong Island  Central and Western
# 1    2021  Public rental housing units  Hong Kong Island            Wan Chai
# 2    2021  Public rental housing units  Hong Kong Island             Eastern
# 3    2021  Public rental housing units  Hong Kong Island             Southern
# 4    2021  Public rental housing units  Hong Kong Island            Sub-Total
# ..    ...                          ...               ...                  ...
# 142  2021                        Total   New Territories               Tai Po
# 143  2021                        Total   New Territories              Sha Tin
# 144  2021                        Total   New Territories             Sai Kung
# 145  2021                        Total   New Territories              Islands
# 146  2021                        Total   New Territories            Sub-Total
#
# ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E210e_OccupiedQuarterByQuarterTypeAndDistrict (Year, QuarterType, Region, District, NumberOfOccupiedQuarters, Description) values(?,?,?,?,?,?)", row.Year, row.QuarterType, row.Region, row.District, toEmptyOrInt(row.NumberOfOccupiedQuarters), row.Description) 
cnxn.commit()
cursor.close()

# %%
df301 = xl.parse("E301e")

# %%
df301 = df301.iloc[1:457, :-2]

# %%
df301
# Out:
#     Table E301 : Median Monthly Domestic Household Mortgage Payment and Loan Repayment, Median Mortgage Payment and Loan Repayment to Income Ratio by District Council/ Constituency Area and Year  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4                  District Council/ Constituency Area
# 5                        Central & Western - Chung Wan
# ..                                                 ...
# 452                         Islands - Tung Chung North
# 453                            Islands - Discovery Bay
# 454                Islands - Peng Chau & Hei Ling Chau
# 455                           Islands - Lamma & Po Toi
# 456                              Islands - Cheung Chau
#
#                                             Unnamed: 1  \
# 1    Median Monthly Domestic Household Mortgage Pay...
# ...

# %%
result_df = pd.DataFrame()

# %%
for i in range(4,456):
    new_row = [2021, df301.iloc[i,0].split("-")[0].strip(), df301.iloc[i,0].split("-")[1].strip(), df301.iloc[i,1], df301.iloc[i,2], "Median monthly mortgage payment expressed in HK$; Median mortgage payment to income ratio expressed in percentage;"]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "District", "ConstituencyArea", "MedianMonthlyMortgagePayment", "MedianMortgagePaymentToIncomeRatio", "Description"]

# %%
result_df
# Out:
#      Year           District           ConstituencyArea  \
# 0    2021  Central & Western                  Chung Wan
# 1    2021  Central & Western            Mid Levels East
# 2    2021  Central & Western                Castle Road
# 3    2021  Central & Western                       Peak
# 4    2021  Central & Western                 University
# ..    ...                ...                        ...
# 447  2021            Islands           Tung Chung North
# 448  2021            Islands              Discovery Bay
# 449  2021            Islands  Peng Chau & Hei Ling Chau
# 450  2021            Islands             Lamma & Po Toi
# 451  2021            Islands                Cheung Chau
#
#     MedianMonthlyMortgagePayment MedianMortgagePaymentToIncomeRatio  \
# 0                          15000                               23.8
# 1                          18000                               20.1
# 2                          30000                               21.1
# ...

# %%
def toEmptyOrInt(value):
    if (str(value) == "--" or str(value) == "***"):
        pass
    else:
        return int(value)

# %%
def toEmptyOrFloat(value):
    if (str(value) == "--" or str(value) == "***"):
        pass
    else:
        return float(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E301e_MortgagePaymentByConstituencyArea (Year, District, ConstituencyArea, MedianMonthlyMortgagePayment, MedianMortgagePaymentToIncomeRatio, Description) values(?,?,?,?,?,?)", row.Year, row.District, row.ConstituencyArea, toEmptyOrInt(row.MedianMonthlyMortgagePayment), toEmptyOrFloat(row.MedianMortgagePaymentToIncomeRatio), row.Description) 
cnxn.commit()
cursor.close()

# %%
df302 = xl.parse("E302e")

# %%
df302 = df302.iloc[1:457, :-2]

# %%
df302
# Out:
#     Table E302 : Median Monthly Domestic Household Rent, Median Rent to Income Ratio by District Council/ Constituency Area and Year  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4                  District Council/ Constituency Area
# 5                        Central & Western - Chung Wan
# ..                                                 ...
# 452                         Islands - Tung Chung North
# 453                            Islands - Discovery Bay
# 454                Islands - Peng Chau & Hei Ling Chau
# 455                           Islands - Lamma & Po Toi
# 456                              Islands - Cheung Chau
#
#                                      Unnamed: 1  \
# 1    Median Monthly Domestic Household Rent (1)
# 2                                           HK$
# 3                                          2021
# ...

# %%
result_df = pd.DataFrame()

# %%
for i in range(4,456):
    new_row = [2021, df302.iloc[i,0].split("-")[0].strip(), df302.iloc[i,0].split("-")[1].strip(), df302.iloc[i,1], df302.iloc[i,2], "Median monthly rent expressed in HK$ and median rent to income ratio expressed in percentage"]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "District", "ConstituencyArea", "MedianMonthlyRent", "MedianRentToIncomeRatio", "Description"]

# %%
result_df
# Out:
#      Year           District           ConstituencyArea MedianMonthlyRent  \
# 0    2021  Central & Western                  Chung Wan             14850
# 1    2021  Central & Western            Mid Levels East             25500
# 2    2021  Central & Western                Castle Road             36000
# 3    2021  Central & Western                       Peak             80000
# 4    2021  Central & Western                 University             33500
# ..    ...                ...                        ...               ...
# 447  2021            Islands           Tung Chung North              2000
# 448  2021            Islands              Discovery Bay             24000
# 449  2021            Islands  Peng Chau & Hei Ling Chau              6000
# 450  2021            Islands             Lamma & Po Toi             11000
# 451  2021            Islands                Cheung Chau              3360
#
#     MedianRentToIncomeRatio                                        Description
# ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E302e_RentByConstituencyArea (Year, District, ConstituencyArea, MedianMonthlyRent, MedianRentToIncomeRatio, Description) values(?,?,?,?,?,?)", row.Year, row.District, row.ConstituencyArea, toEmptyOrInt(row.MedianMonthlyRent), toEmptyOrFloat(row.MedianRentToIncomeRatio), row.Description) 
cnxn.commit()
cursor.close()

# %%
df303 = xl.parse("E303e")

# %%
df303 = df303.iloc[1:458,:-2]

# %%
df303
# Out:
#     Table E303 : Domestic Households by District Council/ Constituency Area, Year and Tenure of Accommodation  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4                              Tenure of Accommodation
# 5                  District Council/ Constituency Area
# ..                                                 ...
# 453                         Islands - Tung Chung North
# 454                            Islands - Discovery Bay
# 455                Islands - Peng Chau & Hei Ling Chau
# 456                           Islands - Lamma & Po Toi
# 457                              Islands - Cheung Chau
#
#                                  Unnamed: 1  \
# 1                       Domestic Households
# 2                                    Number
# 3                                      2021
# 4    Owner-occupier - With mortgage or loan
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, tenure in enumerate(df303.iloc[3,1:]):
    for inner_idx, constituencyArea in enumerate(df303.iloc[5:,0]):
        new_row = [2021, tenure, constituencyArea.split("-")[0].strip(), constituencyArea.split("-")[1].strip(), df303.iloc[5+inner_idx,1+idx], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "TenureOfAccommodation", "District", "ConstituencyArea", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#       Year                   TenureOfAccommodation           District  \
# 0     2021  Owner-occupier - With mortgage or loan  Central & Western
# 1     2021  Owner-occupier - With mortgage or loan  Central & Western
# 2     2021  Owner-occupier - With mortgage or loan  Central & Western
# 3     2021  Owner-occupier - With mortgage or loan  Central & Western
# 4     2021  Owner-occupier - With mortgage or loan  Central & Western
# ...    ...                                     ...                ...
# 3159  2021                                   Total            Islands
# 3160  2021                                   Total            Islands
# 3161  2021                                   Total            Islands
# 3162  2021                                   Total            Islands
# 3163  2021                                   Total            Islands
#
#                ConstituencyArea NumberOfHouseholds Description
# 0                     Chung Wan                519
# ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E303e_HouseholdByTenureAndConstituencyArea (Year, TenureOfAccommodation, District, ConstituencyArea, NumberOfHouseholds, Description) values(?,?,?,?,?,?)", row.Year, row.TenureOfAccommodation, row.District, row.ConstituencyArea, toEmptyOrInt(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df304 = xl.parse("E304e")

# %%
df304 = df304.iloc[1:458,:-2]

# %%
df304
# Out:
#     Table E304 : Occupied Quarters by District Council/ Constituency Area, Year and Type of Quarters  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4                                     Type of Quarters
# 5                  District Council/ Constituency Area
# ..                                                 ...
# 453                         Islands - Tung Chung North
# 454                            Islands - Discovery Bay
# 455                Islands - Peng Chau & Hei Ling Chau
# 456                           Islands - Lamma & Po Toi
# 457                              Islands - Cheung Chau
#
#                       Unnamed: 1             Unnamed: 2  \
# 1              Occupied Quarters                    NaN
# 2     Number of Unit of Quarters                    NaN
# 3                           2021                    NaN
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, quarterType in enumerate(df304.iloc[3,1:]):
    for inner_idx, constituencyArea in enumerate(df304.iloc[5:,0]):
        new_row = [2021, quarterType, constituencyArea.split("-")[0].strip(), constituencyArea.split("-")[1].strip(), df304.iloc[5+inner_idx,1+idx], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "QuarterType", "District", "ConstituencyArea", "NumberOfOccupiedQuarters", "Description"]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E304e_OccupiedQuarterByQuarterTypeAndConstituencyArea (Year, QuarterType, District, ConstituencyArea, NumberOfOccupiedQuarters, Description) values(?,?,?,?,?,?)", row.Year, row.QuarterType, row.District, row.ConstituencyArea, toEmptyOrInt(row.NumberOfOccupiedQuarters), row.Description) 
cnxn.commit()
cursor.close()

# %%
df305 = xl.parse("E305e")

# %%
df305 = df305.iloc[1:458,:-2]

# %%
df305
# Out:
#     Table E305 : Population by District Council/ Constituency Area, Year and Type of Housing  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4                                      Type of Housing
# 5                  District Council/ Constituency Area
# ..                                                 ...
# 453                         Islands - Tung Chung North
# 454                            Islands - Discovery Bay
# 455                Islands - Peng Chau & Hei Ling Chau
# 456                           Islands - Lamma & Po Toi
# 457                              Islands - Cheung Chau
#
#                 Unnamed: 1                         Unnamed: 2  \
# 1               Population                                NaN
# 2        Number of Persons                                NaN
# 3                     2021                                NaN
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df305.iloc[3,1:]):
    for inner_idx, constituencyArea in enumerate(df305.iloc[5:,0]):
        new_row = [2021, housingType, constituencyArea.split("-")[0].strip(), constituencyArea.split("-")[1].strip(), df305.iloc[5+inner_idx,1+idx], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "District", "ConstituencyArea", "NumberOfPersons", "Description"]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E305e_PopulationByHousingTypeAndConstituencyArea (Year, HousingType, District, ConstituencyArea, NumberOfPersons, Description) values(?,?,?,?,?,?)", row.Year, row.HousingType, row.District, row.ConstituencyArea, toEmptyOrInt(row.NumberOfPersons), row.Description) 
cnxn.commit()
cursor.close()

# %%
df401 = xl.parse("E401e")

# %%
df401 = df401.iloc[1:165,:-2]

# %%
df401
# Out:
#     Table E401 : Domestic Households by Large Tertiary Planning Unit Group, Year and Monthly Domestic Household Mortgage Payment and Loan Repayment (HK$)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4    Monthly Domestic Household Mortgage Payment an...
# 5                   Large Tertiary Planning Unit Group
# ..                                                 ...
# 160                                                920
# 161                                          950 - 951
# 162                                  961 - 963 and 976
# 163                                          971 - 974
# 164                                                975
#
#                         Unnamed: 1 Unnamed: 2     Unnamed: 3       Unnamed: 4  \
# 1              Domestic Households        NaN            NaN              NaN
# ...

# %%
result_df = pd.DataFrame()

# %%
for idx, mortgagePayment in enumerate(df401.iloc[3,1:]):
    for inner_idx, tertiaryPlanning in enumerate(df401.iloc[5:,0]):
        new_row = [2021, mortgagePayment, tertiaryPlanning, df401.iloc[5+inner_idx, 1+idx], "Monthly mortgage payment range expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "MonthlyMortgagePaymentRange", "TertiaryPlanningUnit", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#      Year    MonthlyMortgagePaymentRange     TertiaryPlanningUnit  \
# 0    2021  By non-household members only                      111
# 1    2021  By non-household members only              112 and 115
# 2    2021  By non-household members only                113 - 114
# 3    2021  By non-household members only                      116
# 4    2021  By non-household members only  121 - 124 and 133 - 135
# ..    ...                            ...                      ...
# 949  2021                          Total                      920
# 950  2021                          Total                950 - 951
# 951  2021                          Total        961 - 963 and 976
# 952  2021                          Total                971 - 974
# 953  2021                          Total                      975
#
#     NumberOfHouseholds                                      Description
# 0                  364  Monthly mortgage payment range expressed in HK$
# ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E401e_HouseholdByMortgagePaymentAndTertiaryPlanningUnit (Year, MonthlyMortgagePaymentRange, TertiaryPlanningUnit, NumberOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.MonthlyMortgagePaymentRange, row.TertiaryPlanningUnit, toEmptyOrInt(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()
