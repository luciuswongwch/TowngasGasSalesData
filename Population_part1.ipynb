# %%
import pandas as pd
import numpy as np

# %%
file_name = "./data/Population 2021.xlsx"

# %%
xl = pd.ExcelFile(file_name)
for sheet in xl.sheet_names:
    print(sheet)
# Out:
# 索引 Index
# E101e
# E102e
# E103e
# E104e
# E105e
# E106ae
# E106be
# E106ce
# E107ae
# E107be
# E108ae
# E108be
# E109e
# E110e
# E111ae
# E111be
# E111ce
# E111de
# E112e
# E113e
# E114e
# E115e
# E116e
# E117e
# E118ae
# E118be
# E119e
# E201ae
# E201be
# E201ce
# E201de
# E201ee
# E202e
# E203e
# E204e
# E205e
# E206e
# E207e
# E208e
# E209e
# E210e
# E301e
# E302e
# E303e
# E304e
# E305e
# E401e

# %%
df = xl.parse("E101e")

# %%
df = df.iloc[1:11,:7]

# %%
columns = ["Year", "TypeOfHousing", "NumberOfPersons", "PercentageOfPopulation", "Description"]

# %%
df.drop(2, inplace=True)

# %%
df = df.fillna(method="ffill", axis=1)
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_12756\1104005631.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill", axis=1)

# %%
df
# Out:
#    Table E101 : Population by Type of Housing and Year         Unnamed: 1  \
# 1                                                Year                2011
# 3                                                 NaN   Number of Persons
# 4                                     Type of Housing     Type of Housing
# 5                               Public rental housing             2092638
# 6                   Subsidised home ownership housing             1205391
# 7                           Private permanent housing             3640206
# 8                                Non-domestic housing               85632
# 9                                   Temporary housing               47709
# 10                                              Total             7071576
#
#          Unnamed: 2         Unnamed: 3       Unnamed: 4         Unnamed: 5  \
# 1              2011               2016             2016               2021
# 3        Percentage  Number of Persons       Percentage  Number of Persons
# 4   Type of Housing    Type of Housing  Type of Housing    Type of Housing
# 5              29.6            2131553             29.1            2175360
# 6                17            1161166             15.8            1161105
# 7              51.5            3901743             53.2            3921781
# 8               1.2              87526              1.2              92416
# 9               0.7              54597              0.7              62408
# 10              100            7336585              100            7413070
#
#          Unnamed: 6
# 1              2021
# 3        Percentage
# 4   Type of Housing
# 5              29.3
# 6              15.7
# 7              52.9
# 8               1.2
# 9               0.8
# 10              100

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df.iloc[0, 1:].drop_duplicates()):
    for inner_idx, housingType in enumerate(df.iloc[3:,0]):
        new_row = [year, housingType, df.iloc[inner_idx + 3, idx * 2 + 1], df.iloc[inner_idx + 3, idx * 2 + 2], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = columns

# %%
result_df
# Out:
#     Year                      TypeOfHousing  NumberOfPersons  \
# 0   2011              Public rental housing          2092638
# 1   2011  Subsidised home ownership housing          1205391
# 2   2011          Private permanent housing          3640206
# 3   2011               Non-domestic housing            85632
# 4   2011                  Temporary housing            47709
# 5   2011                              Total          7071576
# 6   2016              Public rental housing          2131553
# 7   2016  Subsidised home ownership housing          1161166
# 8   2016          Private permanent housing          3901743
# 9   2016               Non-domestic housing            87526
# 10  2016                  Temporary housing            54597
# 11  2016                              Total          7336585
# 12  2021              Public rental housing          2175360
# 13  2021  Subsidised home ownership housing          1161105
# 14  2021          Private permanent housing          3921781
# 15  2021               Non-domestic housing            92416
# 16  2021                  Temporary housing            62408
# 17  2021                              Total          7413070
#
#     PercentageOfPopulation                          Description
# 0                     29.6  Population by housing type and year
# 1                     17.0  Population by housing type and year
# 2                     51.5  Population by housing type and year
# 3                      1.2  Population by housing type and year
# 4                      0.7  Population by housing type and year
# 5                    100.0  Population by housing type and year
# 6                     29.1  Population by housing type and year
# 7                     15.8  Population by housing type and year
# 8                     53.2  Population by housing type and year
# 9                      1.2  Population by housing type and year
# 10                     0.7  Population by housing type and year
# 11                   100.0  Population by housing type and year
# 12                    29.3  Population by housing type and year
# 13                    15.7  Population by housing type and year
# 14                    52.9  Population by housing type and year
# 15                     1.2  Population by housing type and year
# 16                     0.8  Population by housing type and year
# 17                   100.0  Population by housing type and year

# %%
import pyodbc

# %%
server = "db-at-dev-01.database.windows.net"
database = "db-at-dev-gas-sale-01"
username = "sqladmin"
password = "Password2025"

# %%
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E101e_PopulationByHousingTypeAndYear (Year, TypeOfHousing, NumberOfPersons, PercentageOfPopulation, Description) values(?,?,?,?,?)", row.Year, row.TypeOfHousing, row.NumberOfPersons, row.PercentageOfPopulation, row.Description) 
cnxn.commit()
cursor.close()

# %%
df2 = xl.parse("E102e")

# %%
df2 = df2.iloc[1:13, :8]

# %%
df2
# Out:
#    Table E102 : Domestic Households (Excluding those Living on Board Vessels) by Tenure of Accommodation and Year  \
# 1                                                Year
# 2                                                 NaN
# 3                                                 NaN
# 4   Tenure of Accommodation - Owner-occupier/ Sole...
# 5                                      Owner-occupier
# 6                                                 NaN
# 7                                                 NaN
# 8                                         Sole Tenant
# 9                 Co-tenant/‌ Main tenant/ Sub-tenant
# 10                                             Others
# 11                                                NaN
# 12                                                NaN
#
#                                            Unnamed: 1  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Tenure of Accommodation - 6 Groups (Excluding ...
# 5              Owner-occupier - With mortgage or loan
# 6          Owner-occupier - Without mortgage and loan
# 7                                           Sub-Total
# 8                                                 NaN
# 9                                                 NaN
# 10                                          Rent free
# 11                               Provided by employer
# 12                                          Sub-Total
#
#                                            Unnamed: 2  Unnamed: 3  \
# 1                                                2011         NaN
# 2   Domestic Households (Excluding those Living on...         NaN
# 3                                              Number  Percentage
# 4                                                 NaN         NaN
# 5                                              492261    39.9 (1)
# 6                                              741334    60.1 (1)
# 7                                             1233595        52.1
# 8                                             1039380        43.9
# 9                                               11491         0.5
# 10                                              46781           2
# 11                                              37115         1.6
# 12                                              83896         3.5
#
#                                            Unnamed: 4  Unnamed: 5  \
# 1                                                2016         NaN
# 2   Domestic Households (Excluding those Living on...         NaN
# 3                                              Number  Percentage
# 4                                                 NaN         NaN
# 5                                              417974    34.3 (1)
# 6                                              799029    65.7 (1)
# 7                                             1217003        48.5
# 8                                             1173289        46.8
# 9                                                5710         0.2
# 10                                              74482           3
# 11                                              38853         1.5
# 12                                             113335         4.5
#
#                                            Unnamed: 6  Unnamed: 7
# 1                                                2021         NaN
# 2   Domestic Households (Excluding those Living on...         NaN
# 3                                              Number  Percentage
# 4                                                 NaN         NaN
# 5                                              440160    33.9 (1)
# 6                                              858062    66.1 (1)
# 7                                             1298222        48.6
# 8                                             1270009        47.5
# 9                                                2734         0.1
# 10                                              65424         2.4
# 11                                              37325         1.4
# 12                                             102749         3.8

# %%
df2.iloc[5,0] = df2.iloc[6,0] = "Owner-occupier"

# %%
df2.iloc[10,0] = df2.iloc[11,0] = "Others"

# %%
df2.drop(4)
# Out:
#    Table E102 : Domestic Households (Excluding those Living on Board Vessels) by Tenure of Accommodation and Year  \
# 1                                                Year
# 2                                                 NaN
# 3                                                 NaN
# 5                                      Owner-occupier
# 6                                      Owner-occupier
# 7                                      Owner-occupier
# 8                                         Sole Tenant
# 9                 Co-tenant/‌ Main tenant/ Sub-tenant
# 10                                             Others
# 11                                             Others
# 12                                             Others
#
#                                     Unnamed: 1  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 5       Owner-occupier - With mortgage or loan
# 6   Owner-occupier - Without mortgage and loan
# 7                                    Sub-Total
# 8                                          NaN
# 9                                          NaN
# 10                                   Rent free
# 11                        Provided by employer
# 12                                   Sub-Total
#
#                                            Unnamed: 2  Unnamed: 3  \
# 1                                                2011         NaN
# 2   Domestic Households (Excluding those Living on...         NaN
# 3                                              Number  Percentage
# 5                                              492261    39.9 (1)
# 6                                              741334    60.1 (1)
# 7                                             1233595        52.1
# 8                                             1039380        43.9
# 9                                               11491         0.5
# 10                                              46781           2
# 11                                              37115         1.6
# 12                                              83896         3.5
#
#                                            Unnamed: 4  Unnamed: 5  \
# 1                                                2016         NaN
# 2   Domestic Households (Excluding those Living on...         NaN
# 3                                              Number  Percentage
# 5                                              417974    34.3 (1)
# 6                                              799029    65.7 (1)
# 7                                             1217003        48.5
# 8                                             1173289        46.8
# 9                                                5710         0.2
# 10                                              74482           3
# 11                                              38853         1.5
# 12                                             113335         4.5
#
#                                            Unnamed: 6  Unnamed: 7
# 1                                                2021         NaN
# 2   Domestic Households (Excluding those Living on...         NaN
# 3                                              Number  Percentage
# 5                                              440160    33.9 (1)
# 6                                              858062    66.1 (1)
# 7                                             1298222        48.6
# 8                                             1270009        47.5
# 9                                                2734         0.1
# 10                                              65424         2.4
# 11                                              37325         1.4
# 12                                             102749         3.8

# %%
columns2 = ["Year", "TenureOfAccommodation", "SubGroup", "NumberOfHouseholds", "PercentageOfHouseholds", "Description"]

# %%
result_df = pd.DataFrame()

# %%
import re

# %%
for idx, year in enumerate(df2.iloc[0, 2:].dropna()):
    for inner_idx, tenure in enumerate(df2.iloc[4:,0]):
        new_row = [year, tenure, df2.iloc[inner_idx+4,1], df2.iloc[inner_idx+4,(idx+1)*2], re.sub(r'\([^)]*\)', '', str(df2.iloc[inner_idx+4,(idx+1)*2+1])), ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = columns2

# %%
result_df
# Out:
#     Year                TenureOfAccommodation  \
# 0   2011                       Owner-occupier
# 1   2011                       Owner-occupier
# 2   2011                       Owner-occupier
# 3   2011                          Sole Tenant
# 4   2011  Co-tenant/‌ Main tenant/ Sub-tenant
# 5   2011                               Others
# 6   2011                               Others
# 7   2011                               Others
# 8   2016                       Owner-occupier
# 9   2016                       Owner-occupier
# 10  2016                       Owner-occupier
# 11  2016                          Sole Tenant
# 12  2016  Co-tenant/‌ Main tenant/ Sub-tenant
# 13  2016                               Others
# 14  2016                               Others
# 15  2016                               Others
# 16  2021                       Owner-occupier
# 17  2021                       Owner-occupier
# 18  2021                       Owner-occupier
# 19  2021                          Sole Tenant
# 20  2021  Co-tenant/‌ Main tenant/ Sub-tenant
# 21  2021                               Others
# 22  2021                               Others
# 23  2021                               Others
#
#                                       SubGroup  NumberOfHouseholds  \
# 0       Owner-occupier - With mortgage or loan              492261
# 1   Owner-occupier - Without mortgage and loan              741334
# 2                                    Sub-Total             1233595
# 3                                          NaN             1039380
# 4                                          NaN               11491
# 5                                    Rent free               46781
# 6                         Provided by employer               37115
# 7                                    Sub-Total               83896
# 8       Owner-occupier - With mortgage or loan              417974
# 9   Owner-occupier - Without mortgage and loan              799029
# 10                                   Sub-Total             1217003
# 11                                         NaN             1173289
# 12                                         NaN                5710
# 13                                   Rent free               74482
# 14                        Provided by employer               38853
# 15                                   Sub-Total              113335
# 16      Owner-occupier - With mortgage or loan              440160
# 17  Owner-occupier - Without mortgage and loan              858062
# 18                                   Sub-Total             1298222
# 19                                         NaN             1270009
# 20                                         NaN                2734
# 21                                   Rent free               65424
# 22                        Provided by employer               37325
# 23                                   Sub-Total              102749
#
#    PercentageOfHouseholds                                        Description
# 0                 20.7879  Domestic Household by Tenure and Year. Domesti...
# 1                 31.3121  Domestic Household by Tenure and Year. Domesti...
# 2                    52.1  Domestic Household by Tenure and Year. Domesti...
# 3                    43.9  Domestic Household by Tenure and Year. Domesti...
# 4                     0.5  Domestic Household by Tenure and Year. Domesti...
# 5                       2  Domestic Household by Tenure and Year. Domesti...
# 6                     1.6  Domestic Household by Tenure and Year. Domesti...
# 7                     3.5  Domestic Household by Tenure and Year. Domesti...
# 8                 16.6355  Domestic Household by Tenure and Year. Domesti...
# 9                 31.8645  Domestic Household by Tenure and Year. Domesti...
# 10                   48.5  Domestic Household by Tenure and Year. Domesti...
# 11                   46.8  Domestic Household by Tenure and Year. Domesti...
# 12                    0.2  Domestic Household by Tenure and Year. Domesti...
# 13                      3  Domestic Household by Tenure and Year. Domesti...
# 14                    1.5  Domestic Household by Tenure and Year. Domesti...
# 15                    4.5  Domestic Household by Tenure and Year. Domesti...
# 16                16.4754  Domestic Household by Tenure and Year. Domesti...
# 17                32.1246  Domestic Household by Tenure and Year. Domesti...
# 18                   48.6  Domestic Household by Tenure and Year. Domesti...
# 19                   47.5  Domestic Household by Tenure and Year. Domesti...
# 20                    0.1  Domestic Household by Tenure and Year. Domesti...
# 21                    2.4  Domestic Household by Tenure and Year. Domesti...
# 22                    1.4  Domestic Household by Tenure and Year. Domesti...
# 23                    3.8  Domestic Household by Tenure and Year. Domesti...

# %%
result_df.iloc[0, 4] = float(result_df.iloc[0, 4]) / 100 * float(result_df.iloc[2, 4])

# %%
result_df.iloc[1, 4] = float(result_df.iloc[1, 4]) / 100 * float(result_df.iloc[2, 4])

# %%
result_df.iloc[3,1] = result_df.iloc[4,1] = result_df.iloc[11,1] = result_df.iloc[12,1] = result_df.iloc[19,1] = result_df.iloc[20,1] = "Sub-Total"

# %%
result_df
# Out:
#     Year                TenureOfAccommodation  \
# 0   2011                       Owner-occupier
# 1   2011                       Owner-occupier
# 2   2011                       Owner-occupier
# 3   2011                          Sole Tenant
# 4   2011  Co-tenant/‌ Main tenant/ Sub-tenant
# 5   2011                               Others
# 6   2011                               Others
# 7   2011                               Others
# 8   2016                       Owner-occupier
# 9   2016                       Owner-occupier
# 10  2016                       Owner-occupier
# 11  2016                          Sole Tenant
# 12  2016  Co-tenant/‌ Main tenant/ Sub-tenant
# 13  2016                               Others
# 14  2016                               Others
# 15  2016                               Others
# 16  2021                       Owner-occupier
# 17  2021                       Owner-occupier
# 18  2021                       Owner-occupier
# 19  2021                          Sole Tenant
# 20  2021  Co-tenant/‌ Main tenant/ Sub-tenant
# 21  2021                               Others
# 22  2021                               Others
# 23  2021                               Others
#
#                                       SubGroup  NumberOfDomesticHouseholds  \
# 0       Owner-occupier - With mortgage or loan                      492261
# 1   Owner-occupier - Without mortgage and loan                      741334
# 2                                    Sub-Total                     1233595
# 3                                          NaN                     1039380
# 4                                          NaN                       11491
# 5                                    Rent free                       46781
# 6                         Provided by employer                       37115
# 7                                    Sub-Total                       83896
# 8       Owner-occupier - With mortgage or loan                      417974
# 9   Owner-occupier - Without mortgage and loan                      799029
# 10                                   Sub-Total                     1217003
# 11                                         NaN                     1173289
# 12                                         NaN                        5710
# 13                                   Rent free                       74482
# 14                        Provided by employer                       38853
# 15                                   Sub-Total                      113335
# 16      Owner-occupier - With mortgage or loan                      440160
# 17  Owner-occupier - Without mortgage and loan                      858062
# 18                                   Sub-Total                     1298222
# 19                                         NaN                     1270009
# 20                                         NaN                        2734
# 21                                   Rent free                       65424
# 22                        Provided by employer                       37325
# 23                                   Sub-Total                      102749
#
#    PercentageOfDomesticHouseholds  \
# 0                         20.7879
# 1                         31.3121
# 2                            52.1
# 3                            43.9
# 4                             0.5
# 5                               2
# 6                             1.6
# 7                             3.5
# 8                           34.3
# 9                           65.7
# 10                           48.5
# 11                           46.8
# 12                            0.2
# 13                              3
# 14                            1.5
# 15                            4.5
# 16                          33.9
# 17                          66.1
# 18                           48.6
# 19                           47.5
# 20                            0.1
# 21                            2.4
# 22                            1.4
# 23                            3.8
#
#                                           Description
# 0   Domestic Household by Tenure and Year. Domesti...
# 1   Domestic Household by Tenure and Year. Domesti...
# 2   Domestic Household by Tenure and Year. Domesti...
# 3   Domestic Household by Tenure and Year. Domesti...
# 4   Domestic Household by Tenure and Year. Domesti...
# 5   Domestic Household by Tenure and Year. Domesti...
# 6   Domestic Household by Tenure and Year. Domesti...
# 7   Domestic Household by Tenure and Year. Domesti...
# 8   Domestic Household by Tenure and Year. Domesti...
# 9   Domestic Household by Tenure and Year. Domesti...
# 10  Domestic Household by Tenure and Year. Domesti...
# 11  Domestic Household by Tenure and Year. Domesti...
# 12  Domestic Household by Tenure and Year. Domesti...
# 13  Domestic Household by Tenure and Year. Domesti...
# 14  Domestic Household by Tenure and Year. Domesti...
# 15  Domestic Household by Tenure and Year. Domesti...
# 16  Domestic Household by Tenure and Year. Domesti...
# 17  Domestic Household by Tenure and Year. Domesti...
# 18  Domestic Household by Tenure and Year. Domesti...
# 19  Domestic Household by Tenure and Year. Domesti...
# 20  Domestic Household by Tenure and Year. Domesti...
# 21  Domestic Household by Tenure and Year. Domesti...
# 22  Domestic Household by Tenure and Year. Domesti...
# 23  Domestic Household by Tenure and Year. Domesti...

# %%
result_df.iloc[8, 4] = float(result_df.iloc[8, 4]) / 100 * float(result_df.iloc[10, 4])
result_df.iloc[9, 4] = float(result_df.iloc[9, 4]) / 100 * float(result_df.iloc[10, 4])
result_df.iloc[16, 4] = float(result_df.iloc[16, 4]) / 100 * float(result_df.iloc[18, 4])
result_df.iloc[17, 4] = float(result_df.iloc[17, 4]) / 100 * float(result_df.iloc[18, 4])

# %%
result_df
# Out:
#     Year                TenureOfAccommodation  \
# 0   2011                       Owner-occupier
# 1   2011                       Owner-occupier
# 2   2011                       Owner-occupier
# 3   2011                          Sole Tenant
# 4   2011  Co-tenant/‌ Main tenant/ Sub-tenant
# 5   2011                               Others
# 6   2011                               Others
# 7   2011                               Others
# 8   2016                       Owner-occupier
# 9   2016                       Owner-occupier
# 10  2016                       Owner-occupier
# 11  2016                          Sole Tenant
# 12  2016  Co-tenant/‌ Main tenant/ Sub-tenant
# 13  2016                               Others
# 14  2016                               Others
# 15  2016                               Others
# 16  2021                       Owner-occupier
# 17  2021                       Owner-occupier
# 18  2021                       Owner-occupier
# 19  2021                          Sole Tenant
# 20  2021  Co-tenant/‌ Main tenant/ Sub-tenant
# 21  2021                               Others
# 22  2021                               Others
# 23  2021                               Others
#
#                                       SubGroup  NumberOfDomesticHouseholds  \
# 0       Owner-occupier - With mortgage or loan                      492261
# 1   Owner-occupier - Without mortgage and loan                      741334
# 2                                    Sub-Total                     1233595
# 3                                          NaN                     1039380
# 4                                          NaN                       11491
# 5                                    Rent free                       46781
# 6                         Provided by employer                       37115
# 7                                    Sub-Total                       83896
# 8       Owner-occupier - With mortgage or loan                      417974
# 9   Owner-occupier - Without mortgage and loan                      799029
# 10                                   Sub-Total                     1217003
# 11                                         NaN                     1173289
# 12                                         NaN                        5710
# 13                                   Rent free                       74482
# 14                        Provided by employer                       38853
# 15                                   Sub-Total                      113335
# 16      Owner-occupier - With mortgage or loan                      440160
# 17  Owner-occupier - Without mortgage and loan                      858062
# 18                                   Sub-Total                     1298222
# 19                                         NaN                     1270009
# 20                                         NaN                        2734
# 21                                   Rent free                       65424
# 22                        Provided by employer                       37325
# 23                                   Sub-Total                      102749
#
#    PercentageOfDomesticHouseholds  \
# 0                         20.7879
# 1                         31.3121
# 2                            52.1
# 3                            43.9
# 4                             0.5
# 5                               2
# 6                             1.6
# 7                             3.5
# 8                         16.6355
# 9                         31.8645
# 10                           48.5
# 11                           46.8
# 12                            0.2
# 13                              3
# 14                            1.5
# 15                            4.5
# 16                        16.4754
# 17                        32.1246
# 18                           48.6
# 19                           47.5
# 20                            0.1
# 21                            2.4
# 22                            1.4
# 23                            3.8
#
#                                           Description
# 0   Domestic Household by Tenure and Year. Domesti...
# 1   Domestic Household by Tenure and Year. Domesti...
# 2   Domestic Household by Tenure and Year. Domesti...
# 3   Domestic Household by Tenure and Year. Domesti...
# 4   Domestic Household by Tenure and Year. Domesti...
# 5   Domestic Household by Tenure and Year. Domesti...
# 6   Domestic Household by Tenure and Year. Domesti...
# 7   Domestic Household by Tenure and Year. Domesti...
# 8   Domestic Household by Tenure and Year. Domesti...
# 9   Domestic Household by Tenure and Year. Domesti...
# 10  Domestic Household by Tenure and Year. Domesti...
# 11  Domestic Household by Tenure and Year. Domesti...
# 12  Domestic Household by Tenure and Year. Domesti...
# 13  Domestic Household by Tenure and Year. Domesti...
# 14  Domestic Household by Tenure and Year. Domesti...
# 15  Domestic Household by Tenure and Year. Domesti...
# 16  Domestic Household by Tenure and Year. Domesti...
# 17  Domestic Household by Tenure and Year. Domesti...
# 18  Domestic Household by Tenure and Year. Domesti...
# 19  Domestic Household by Tenure and Year. Domesti...
# 20  Domestic Household by Tenure and Year. Domesti...
# 21  Domestic Household by Tenure and Year. Domesti...
# 22  Domestic Household by Tenure and Year. Domesti...
# 23  Domestic Household by Tenure and Year. Domesti...

# %%
result_df.iloc[4, 1] = result_df.iloc[12, 1] = result_df.iloc[20, 1] = "Co-tenant/ Main tenant/ Sub-tenant"

# %%
result_df
# Out:
#     Year               TenureOfAccommodation  \
# 0   2011                      Owner-occupier
# 1   2011                      Owner-occupier
# 2   2011                      Owner-occupier
# 3   2011                         Sole Tenant
# 4   2011  Co-tenant/ Main tenant/ Sub-tenant
# 5   2011                              Others
# 6   2011                              Others
# 7   2011                              Others
# 8   2016                      Owner-occupier
# 9   2016                      Owner-occupier
# 10  2016                      Owner-occupier
# 11  2016                         Sole Tenant
# 12  2016  Co-tenant/ Main tenant/ Sub-tenant
# 13  2016                              Others
# 14  2016                              Others
# 15  2016                              Others
# 16  2021                      Owner-occupier
# 17  2021                      Owner-occupier
# 18  2021                      Owner-occupier
# 19  2021                         Sole Tenant
# 20  2021  Co-tenant/ Main tenant/ Sub-tenant
# 21  2021                              Others
# 22  2021                              Others
# 23  2021                              Others
#
#                                       SubGroup  NumberOfHouseholds  \
# 0       Owner-occupier - With mortgage or loan              492261
# 1   Owner-occupier - Without mortgage and loan              741334
# 2                                    Sub-Total             1233595
# 3                                          NaN             1039380
# 4                                          NaN               11491
# 5                                    Rent free               46781
# 6                         Provided by employer               37115
# 7                                    Sub-Total               83896
# 8       Owner-occupier - With mortgage or loan              417974
# 9   Owner-occupier - Without mortgage and loan              799029
# 10                                   Sub-Total             1217003
# 11                                         NaN             1173289
# 12                                         NaN                5710
# 13                                   Rent free               74482
# 14                        Provided by employer               38853
# 15                                   Sub-Total              113335
# 16      Owner-occupier - With mortgage or loan              440160
# 17  Owner-occupier - Without mortgage and loan              858062
# 18                                   Sub-Total             1298222
# 19                                         NaN             1270009
# 20                                         NaN                2734
# 21                                   Rent free               65424
# 22                        Provided by employer               37325
# 23                                   Sub-Total              102749
#
#    PercentageOfHouseholds                                        Description
# 0                 20.7879  Domestic Household by Tenure and Year. Domesti...
# 1                 31.3121  Domestic Household by Tenure and Year. Domesti...
# 2                    52.1  Domestic Household by Tenure and Year. Domesti...
# 3                    43.9  Domestic Household by Tenure and Year. Domesti...
# 4                     0.5  Domestic Household by Tenure and Year. Domesti...
# 5                       2  Domestic Household by Tenure and Year. Domesti...
# 6                     1.6  Domestic Household by Tenure and Year. Domesti...
# 7                     3.5  Domestic Household by Tenure and Year. Domesti...
# 8                 16.6355  Domestic Household by Tenure and Year. Domesti...
# 9                 31.8645  Domestic Household by Tenure and Year. Domesti...
# 10                   48.5  Domestic Household by Tenure and Year. Domesti...
# 11                   46.8  Domestic Household by Tenure and Year. Domesti...
# 12                    0.2  Domestic Household by Tenure and Year. Domesti...
# 13                      3  Domestic Household by Tenure and Year. Domesti...
# 14                    1.5  Domestic Household by Tenure and Year. Domesti...
# 15                    4.5  Domestic Household by Tenure and Year. Domesti...
# 16                16.4754  Domestic Household by Tenure and Year. Domesti...
# 17                32.1246  Domestic Household by Tenure and Year. Domesti...
# 18                   48.6  Domestic Household by Tenure and Year. Domesti...
# 19                   47.5  Domestic Household by Tenure and Year. Domesti...
# 20                    0.1  Domestic Household by Tenure and Year. Domesti...
# 21                    2.4  Domestic Household by Tenure and Year. Domesti...
# 22                    1.4  Domestic Household by Tenure and Year. Domesti...
# 23                    3.8  Domestic Household by Tenure and Year. Domesti...

# %%
def toEmptyOrString(value):
    if (str(value) == str(np.NaN)):
        pass
    else:
        return str(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E102e_HouseholdByTenureAndYear (Year, TenureOfAccommodation, SubGroup, NumberOfHouseholds, PercentageOfHouseholds, Description) values(?,?,?,?,?,?)", row.Year, row.TenureOfAccommodation, toEmptyOrString(row.SubGroup), row.NumberOfHouseholds, row.PercentageOfHouseholds, row.Description) 
cnxn.commit()
cursor.close()

# %%
df3 = xl.parse("E103e")

# %%
df3
# Out:
#    Table E103 : Domestic Households by Type of Housing and Year  \
# 0                                                 NaN
# 1                                                Year
# 2                                                 NaN
# 3                                                 NaN
# 4                                     Type of Housing
# 5                               Public rental housing
# 6                   Subsidised home ownership housing
# 7                           Private permanent housing
# 8                                Non-domestic housing
# 9                                   Temporary housing
# 10                                              Total
# 11                                                NaN
# 12                                                NaN
# 13                                           Source :
# 14                      2021 Population Census Office
# 15                   Census and Statistics Department
# 16  The Government of the Hong Kong Special Admini...
# 17                  Enquiry telephone no. : 3428 2744
# 18        Enquiry e-mail : census2021@censtatd.gov.hk
# 19                                                NaN
# 20                                    Release date :
# 21                                   28 February 2022
#
#              Unnamed: 1  Unnamed: 2           Unnamed: 3  Unnamed: 4  \
# 0                   NaN         NaN                  NaN         NaN
# 1                  2011         NaN                 2016         NaN
# 2   Domestic Households         NaN  Domestic Households         NaN
# 3                Number  Percentage               Number  Percentage
# 4                   NaN         NaN                  NaN         NaN
# 5                720892        30.4               761905        30.4
# 6                377615        15.9               384006        15.3
# 7               1242982        52.5              1329922          53
# 8                  8396         0.4                12651         0.5
# 9                 18911         0.8                21250         0.8
# 10              2368796         100              2509734         100
# 11                  NaN         NaN                  NaN         NaN
# 12                  NaN         NaN                  NaN         NaN
# 13                  NaN         NaN                  NaN         NaN
# 14                  NaN         NaN                  NaN         NaN
# 15                  NaN         NaN                  NaN         NaN
# 16                  NaN         NaN                  NaN         NaN
# 17                  NaN         NaN                  NaN         NaN
# 18                  NaN         NaN                  NaN         NaN
# 19                  NaN         NaN                  NaN         NaN
# 20                  NaN         NaN                  NaN         NaN
# 21                  NaN         NaN                  NaN         NaN
#
#              Unnamed: 5  Unnamed: 6  Unnamed: 7  索引 Index
# 0                   NaN         NaN         NaN       NaN
# 1                  2021         NaN         NaN       NaN
# 2   Domestic Households         NaN         NaN       NaN
# 3                Number  Percentage         NaN       NaN
# 4                   NaN         NaN         NaN       NaN
# 5                807304        30.2         NaN       NaN
# 6                413788        15.5         NaN       NaN
# 7               1415740        52.9         NaN       NaN
# 8                 13134         0.5         NaN       NaN
# 9                 24195         0.9         NaN       NaN
# 10              2674161         100         NaN       NaN
# 11                  NaN         NaN         NaN       NaN
# 12                  NaN         NaN         NaN       NaN
# 13                  NaN         NaN         NaN       NaN
# 14                  NaN         NaN         NaN       NaN
# 15                  NaN         NaN         NaN       NaN
# 16                  NaN         NaN         NaN       NaN
# 17                  NaN         NaN         NaN       NaN
# 18                  NaN         NaN         NaN       NaN
# 19                  NaN         NaN         NaN       NaN
# 20                  NaN         NaN         NaN       NaN
# 21                  NaN         NaN         NaN       NaN

# %%
df3 = df3.iloc[1:11,:7]

# %%
df3.drop(4, inplace=True)

# %%
df3
# Out:
#    Table E103 : Domestic Households by Type of Housing and Year  \
# 1                                                Year
# 2                                                 NaN
# 3                                                 NaN
# 5                               Public rental housing
# 6                   Subsidised home ownership housing
# 7                           Private permanent housing
# 8                                Non-domestic housing
# 9                                   Temporary housing
# 10                                              Total
#
#              Unnamed: 1  Unnamed: 2           Unnamed: 3  Unnamed: 4  \
# 1                  2011         NaN                 2016         NaN
# 2   Domestic Households         NaN  Domestic Households         NaN
# 3                Number  Percentage               Number  Percentage
# 5                720892        30.4               761905        30.4
# 6                377615        15.9               384006        15.3
# 7               1242982        52.5              1329922          53
# 8                  8396         0.4                12651         0.5
# 9                 18911         0.8                21250         0.8
# 10              2368796         100              2509734         100
#
#              Unnamed: 5  Unnamed: 6
# 1                  2021         NaN
# 2   Domestic Households         NaN
# 3                Number  Percentage
# 5                807304        30.2
# 6                413788        15.5
# 7               1415740        52.9
# 8                 13134         0.5
# 9                 24195         0.9
# 10              2674161         100

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df.iloc[0, 1:].drop_duplicates()):
    for inner_idx, housingType in enumerate(df.iloc[3:,0]):
        new_row = [year, housingType, df.iloc[inner_idx + 3, idx * 2 + 1], df.iloc[inner_idx + 3, idx * 2 + 2], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df
# Out:
#        0                                  1        2      3  \
# 0   2011              Public rental housing  2092638   29.6
# 1   2011  Subsidised home ownership housing  1205391   17.0
# 2   2011          Private permanent housing  3640206   51.5
# 3   2011               Non-domestic housing    85632    1.2
# 4   2011                  Temporary housing    47709    0.7
# 5   2011                              Total  7071576  100.0
# 6   2016              Public rental housing  2131553   29.1
# 7   2016  Subsidised home ownership housing  1161166   15.8
# 8   2016          Private permanent housing  3901743   53.2
# 9   2016               Non-domestic housing    87526    1.2
# 10  2016                  Temporary housing    54597    0.7
# 11  2016                              Total  7336585  100.0
# 12  2021              Public rental housing  2175360   29.3
# 13  2021  Subsidised home ownership housing  1161105   15.7
# 14  2021          Private permanent housing  3921781   52.9
# 15  2021               Non-domestic housing    92416    1.2
# 16  2021                  Temporary housing    62408    0.8
# 17  2021                              Total  7413070  100.0
#
#                                      4
# 0   Household by housing type and year
# 1   Household by housing type and year
# 2   Household by housing type and year
# 3   Household by housing type and year
# 4   Household by housing type and year
# 5   Household by housing type and year
# 6   Household by housing type and year
# 7   Household by housing type and year
# 8   Household by housing type and year
# 9   Household by housing type and year
# 10  Household by housing type and year
# 11  Household by housing type and year
# 12  Household by housing type and year
# 13  Household by housing type and year
# 14  Household by housing type and year
# 15  Household by housing type and year
# 16  Household by housing type and year
# 17  Household by housing type and year

# %%
columns3 = ["Year", "TypeOfHousing", "NumberOfHouseholds", "PercentageOfHouseholds", "Description"]

# %%
result_df.columns = columns3

# %%
result_df
# Out:
#     Year                      TypeOfHousing  NumberOfHouseholds  \
# 0   2011              Public rental housing             2092638
# 1   2011  Subsidised home ownership housing             1205391
# 2   2011          Private permanent housing             3640206
# 3   2011               Non-domestic housing               85632
# 4   2011                  Temporary housing               47709
# 5   2011                              Total             7071576
# 6   2016              Public rental housing             2131553
# 7   2016  Subsidised home ownership housing             1161166
# 8   2016          Private permanent housing             3901743
# 9   2016               Non-domestic housing               87526
# 10  2016                  Temporary housing               54597
# 11  2016                              Total             7336585
# 12  2021              Public rental housing             2175360
# 13  2021  Subsidised home ownership housing             1161105
# 14  2021          Private permanent housing             3921781
# 15  2021               Non-domestic housing               92416
# 16  2021                  Temporary housing               62408
# 17  2021                              Total             7413070
#
#     PercentageOfHouseholds                         Description
# 0                     29.6  Household by housing type and year
# 1                     17.0  Household by housing type and year
# 2                     51.5  Household by housing type and year
# 3                      1.2  Household by housing type and year
# 4                      0.7  Household by housing type and year
# 5                    100.0  Household by housing type and year
# 6                     29.1  Household by housing type and year
# 7                     15.8  Household by housing type and year
# 8                     53.2  Household by housing type and year
# 9                      1.2  Household by housing type and year
# 10                     0.7  Household by housing type and year
# 11                   100.0  Household by housing type and year
# 12                    29.3  Household by housing type and year
# 13                    15.7  Household by housing type and year
# 14                    52.9  Household by housing type and year
# 15                     1.2  Household by housing type and year
# 16                     0.8  Household by housing type and year
# 17                   100.0  Household by housing type and year

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E103e_HouseholdByHousingTypeAndYear (Year, TypeOfHousing, NumberOfHouseholds, PercentageOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.TypeOfHousing, row.NumberOfHouseholds, row.PercentageOfHouseholds, row.Description) 
cnxn.commit()
cursor.close()

# %%
df4 = xl.parse("E104e")

# %%
df4 = df4.iloc[1:12,:-2]

# %%
df4
# Out:
#    Table E104 : Occupied Quarters by Type of Quarters and Year  \
# 1                                                Year
# 2                                                 NaN
# 3                                                 NaN
# 4                                    Type of Quarters
# 5                         Public rental housing units
# 6                               Subsidised sale flats
# 7                           Private residential flats
# 8         Other quarters in private permanent housing
# 9                               Non-domestic quarters
# 10                                 Temporary quarters
# 11                                              Total
#
#                     Unnamed: 1  Unnamed: 2                  Unnamed: 3  \
# 1                         2011         NaN                        2016
# 2            Occupied Quarters         NaN           Occupied Quarters
# 3   Number of Unit of Quarters  Percentage  Number of Unit of Quarters
# 4                          NaN         NaN                         NaN
# 5                       722161        30.3                      763884
# 6                       379002        15.9                      384849
# 7                      1077123        45.2                     1160775
# 8                       169834         7.1                      176098
# 9                        14425         0.6                       19234
# 10                       18580         0.8                       21186
# 11                     2381125         100                     2526026
#
#     Unnamed: 4                  Unnamed: 5  Unnamed: 6
# 1          NaN                        2021         NaN
# 2          NaN           Occupied Quarters         NaN
# 3   Percentage  Number of Unit of Quarters  Percentage
# 4          NaN                         NaN         NaN
# 5         30.2                      808581        30.1
# 6         15.2                      414468        15.4
# 7           46                     1209870          45
# 8            7                      209608         7.8
# 9          0.8                       22054         0.8
# 10         0.8                       24231         0.9
# 11         100                     2688812         100

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df4.iloc[0, 1:].dropna()):
    for inner_idx, quarterType in enumerate(df4.iloc[4:,0]):
        new_row = [year, quarterType, df4.iloc[inner_idx+4,1], df4.iloc[inner_idx+4,2], ""]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
columns4 = ["Year", "QuarterType", "NumberOfOccupiedQuarters", "PercentageOfOccupiedQuarters", "Description"]

# %%
result_df.columns = columns4

# %%
result_df
# Out:
#     Year                                  QuarterType  \
# 0   2011                  Public rental housing units
# 1   2011                        Subsidised sale flats
# 2   2011                    Private residential flats
# 3   2011  Other quarters in private permanent housing
# 4   2011                        Non-domestic quarters
# 5   2011                           Temporary quarters
# 6   2011                                        Total
# 7   2016                  Public rental housing units
# 8   2016                        Subsidised sale flats
# 9   2016                    Private residential flats
# 10  2016  Other quarters in private permanent housing
# 11  2016                        Non-domestic quarters
# 12  2016                           Temporary quarters
# 13  2016                                        Total
# 14  2021                  Public rental housing units
# 15  2021                        Subsidised sale flats
# 16  2021                    Private residential flats
# 17  2021  Other quarters in private permanent housing
# 18  2021                        Non-domestic quarters
# 19  2021                           Temporary quarters
# 20  2021                                        Total
#
#     NumberOfOccupiedQuarters  PercentageOfOccupiedQuarters
# 0                     722161                          30.3
# 1                     379002                          15.9
# 2                    1077123                          45.2
# 3                     169834                           7.1
# 4                      14425                           0.6
# 5                      18580                           0.8
# 6                    2381125                         100.0
# 7                     722161                          30.3
# 8                     379002                          15.9
# 9                    1077123                          45.2
# 10                    169834                           7.1
# 11                     14425                           0.6
# 12                     18580                           0.8
# 13                   2381125                         100.0
# 14                    722161                          30.3
# 15                    379002                          15.9
# 16                   1077123                          45.2
# 17                    169834                           7.1
# 18                     14425                           0.6
# 19                     18580                           0.8
# 20                   2381125                         100.0

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.E104e_OccupiedQuartersByQuarterTypeAndYear (Year, QuarterType, NumberOfOccupiedQuarters, PercentageOfOccupiedQuarters) values(?,?,?,?)", row.Year, row.QuarterType, row.NumberOfOccupiedQuarters, row.PercentageOfOccupiedQuarters) 
cnxn.commit()
cursor.close()

# %%
df6a = xl.parse("E106ae")

# %%
df6a = df6a.iloc[1:8,:4]

# %%
df6a
# Out:
#   Table E106a : Median Monthly Domestic Household Mortgage Payment and Loan Repayment by Type of Housing and Year  \
# 1                                                NaN
# 2                                                NaN
# 3                                               Year
# 4                                    Type of Housing
# 5                  Subsidised home ownership housing
# 6                          Private permanent housing
# 7                                            Overall
#
#                                           Unnamed: 1  Unnamed: 2  Unnamed: 3
# 1  Median Monthly Domestic Household Mortgage Pay...         NaN         NaN
# 2                                                HK$         NaN         NaN
# 3                                               2011      2016.0      2021.0
# 4                                                NaN         NaN         NaN
# 5                                               5000      5480.0      7000.0
# 6                                               8000     10500.0     13500.0
# 7                                               7000      9500.0     12000.0

# %%
columns6a = ["Year", "HousingType", "MedianMonthlyMortagePayment", "Description"]

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df6a.iloc[2, 1:]):
    for inner_idx, housingType in enumerate(df6a.iloc[4:,0]):
        new_row = [int(year), housingType, df6a.iloc[4+inner_idx, idx+1], "Mortage payment expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = columns6a

# %%
result_df
# Out:
#    Year                        HousingType  MedianMonthlyMortagePayment  \
# 0  2011  Subsidised home ownership housing                       5000.0
# 1  2011          Private permanent housing                       8000.0
# 2  2011                            Overall                       7000.0
# 3  2016  Subsidised home ownership housing                       5480.0
# 4  2016          Private permanent housing                      10500.0
# 5  2016                            Overall                       9500.0
# 6  2021  Subsidised home ownership housing                       7000.0
# 7  2021          Private permanent housing                      13500.0
# 8  2021                            Overall                      12000.0
#
#                         Description
# 0  Mortage payment expressed in HK$
# 1  Mortage payment expressed in HK$
# 2  Mortage payment expressed in HK$
# 3  Mortage payment expressed in HK$
# 4  Mortage payment expressed in HK$
# 5  Mortage payment expressed in HK$
# 6  Mortage payment expressed in HK$
# 7  Mortage payment expressed in HK$
# 8  Mortage payment expressed in HK$

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.MortagePaymentByHousingTypeAndYear (Year, HousingType, MedianMonthlyMortagePayment, Description) values(?,?,?,?)", row.Year, row.HousingType, row.MedianMonthlyMortagePayment, row.Description) 
cnxn.commit()
cursor.close()

# %%
df6b = xl.parse("E106be")

# %%
df6b = df6b.iloc[1:8,:4]

# %%
df6b
# Out:
#   Table E106b : Median Mortgage Payment and Loan Repayment to Income Ratio by Type of Housing and Year  \
# 1                                                NaN
# 2                                                NaN
# 3                                               Year
# 4                                    Type of Housing
# 5                  Subsidised home ownership housing
# 6                          Private permanent housing
# 7                                            Overall
#
#                                           Unnamed: 1  Unnamed: 2  Unnamed: 3
# 1  Median Mortgage Payment and Loan Repayment to ...         NaN         NaN
# 2                                         Percentage         NaN         NaN
# 3                                               2011      2016.0      2021.0
# 4                                                NaN         NaN         NaN
# 5                                               17.6        15.5        18.3
# 6                                                 20        19.0        21.2
# 7                                               19.6        18.4        20.8

# %%
columns6b = ["Year", "HousingType", "MedianMortagePaymentToIncomeRatio", "Description"]

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df6b.iloc[2, 1:]):
    for inner_idx, housingType in enumerate(df6b.iloc[4:,0]):
        new_row = [int(year), housingType, df6b.iloc[4+inner_idx, idx+1], "Median mortage payment to income ratio expressed in percentage"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = columns6b

# %%
result_df
# Out:
#    Year                        HousingType  MedianMortagePaymentToIncomeRatio  \
# 0  2011  Subsidised home ownership housing                               17.6
# 1  2011          Private permanent housing                               20.0
# 2  2011                            Overall                               19.6
# 3  2016  Subsidised home ownership housing                               15.5
# 4  2016          Private permanent housing                               19.0
# 5  2016                            Overall                               18.4
# 6  2021  Subsidised home ownership housing                               18.3
# 7  2021          Private permanent housing                               21.2
# 8  2021                            Overall                               20.8
#
#                                          Description
# 0  Median mortage payment to income ratio express...
# 1  Median mortage payment to income ratio express...
# 2  Median mortage payment to income ratio express...
# 3  Median mortage payment to income ratio express...
# 4  Median mortage payment to income ratio express...
# 5  Median mortage payment to income ratio express...
# 6  Median mortage payment to income ratio express...
# 7  Median mortage payment to income ratio express...
# 8  Median mortage payment to income ratio express...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.MortagePaymentToIncomeRatioByHousingTypeAndYear (Year, HousingType, MedianMortagePaymentToIncomeRatio, Description) values(?,?,?,?)", row.Year, row.HousingType, row.MedianMortagePaymentToIncomeRatio, row.Description) 
cnxn.commit()
cursor.close()

# %%
df6c = xl.parse("E106ce")

# %%
df6c = df6c.iloc[1:8,:4]

# %%
columns6c = ["Year", "HousingType", "MedianPeriodOfMortagePayment", "Description"]

# %%
for idx, year in enumerate(df6c.iloc[2, 1:]):
    for inner_idx, housingType in enumerate(df6c.iloc[4:,0]):
        new_row = [int(year), housingType, df6c.iloc[4+inner_idx, idx+1], "Median period of mortage payment expressed in year"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = columns6c

# %%
result_df
# Out:
#    Year                        HousingType  MedianPeriodOfMortagePayment  \
# 0  2011  Subsidised home ownership housing                           8.0
# 1  2011          Private permanent housing                          14.0
# 2  2011                            Overall                          12.0
# 3  2016  Subsidised home ownership housing                           9.0
# 4  2016          Private permanent housing                          17.0
# 5  2016                            Overall                          15.0
# 6  2021  Subsidised home ownership housing                          15.0
# 7  2021          Private permanent housing                          20.0
# 8  2021                            Overall                          20.0
#
#                                          Description
# 0  Median period of mortage payment expressed in ...
# 1  Median period of mortage payment expressed in ...
# 2  Median period of mortage payment expressed in ...
# 3  Median period of mortage payment expressed in ...
# 4  Median period of mortage payment expressed in ...
# 5  Median period of mortage payment expressed in ...
# 6  Median period of mortage payment expressed in ...
# 7  Median period of mortage payment expressed in ...
# 8  Median period of mortage payment expressed in ...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.MortagePaymentPeriodByHousingTypeAndYear (Year, HousingType, MedianPeriodOfMortagePayment, Description) values(?,?,?,?)", row.Year, row.HousingType, row.MedianPeriodOfMortagePayment, row.Description) 
cnxn.commit()
cursor.close()

# %%
df7a = xl.parse("E107ae")

# %%
df7a = df7a.iloc[3:11,:4]

# %%
columns7a = ["Year", "QuarterType", "MedianMonthlyRent", "Description"]

# %%
df7a
# Out:
#    Table E107a : Median Monthly Domestic Household Rent by Type of Quarters and Year  \
# 3                                                Year
# 4                                    Type of Quarters
# 5                         Public rental housing units
# 6                           Private residential flats
# 7         Other quarters in private permanent housing
# 8    Permanent quarters in other types of housing (2)
# 9                              Temporary quarters (3)
# 10                                            Overall
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3
# 3        2011      2016.0      2021.0
# 4         NaN         NaN         NaN
# 5        1210      1500.0      2090.0
# 6        7500     10000.0     12000.0
# 7        3800      6000.0      7800.0
# 8        6000      7500.0      7500.0
# 9        1500      3500.0      3500.0
# 10       1600      2180.0      2900.0

# %%
import re

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df7a.iloc[0, 1:]):
    for inner_idx, quarterType in enumerate(df7a.iloc[2:,0]):
        new_row = [int(year), re.sub(r'\([^)]*\)', '', str(quarterType)), df7a.iloc[inner_idx+2,idx+1], "Monthly rent expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = columns7a

# %%
result_df
# Out:
#     Year                                    QuarterType  MedianMonthlyRent  \
# 0   2011                    Public rental housing units             1210.0
# 1   2011                      Private residential flats             7500.0
# 2   2011    Other quarters in private permanent housing             3800.0
# 3   2011  Permanent quarters in other types of housing              6000.0
# 4   2011                            Temporary quarters              1500.0
# 5   2011                                        Overall             1600.0
# 6   2016                    Public rental housing units             1500.0
# 7   2016                      Private residential flats            10000.0
# 8   2016    Other quarters in private permanent housing             6000.0
# 9   2016  Permanent quarters in other types of housing              7500.0
# 10  2016                            Temporary quarters              3500.0
# 11  2016                                        Overall             2180.0
# 12  2021                    Public rental housing units             2090.0
# 13  2021                      Private residential flats            12000.0
# 14  2021    Other quarters in private permanent housing             7800.0
# 15  2021  Permanent quarters in other types of housing              7500.0
# 16  2021                            Temporary quarters              3500.0
# 17  2021                                        Overall             2900.0
#
#                       Description
# 0   Monthly rent expressed in HK$
# 1   Monthly rent expressed in HK$
# 2   Monthly rent expressed in HK$
# 3   Monthly rent expressed in HK$
# 4   Monthly rent expressed in HK$
# 5   Monthly rent expressed in HK$
# 6   Monthly rent expressed in HK$
# 7   Monthly rent expressed in HK$
# 8   Monthly rent expressed in HK$
# 9   Monthly rent expressed in HK$
# 10  Monthly rent expressed in HK$
# 11  Monthly rent expressed in HK$
# 12  Monthly rent expressed in HK$
# 13  Monthly rent expressed in HK$
# 14  Monthly rent expressed in HK$
# 15  Monthly rent expressed in HK$
# 16  Monthly rent expressed in HK$
# 17  Monthly rent expressed in HK$

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.MonthlyRentByQuarterTypeAndYear (Year, QuarterType, MedianMonthlyRent, Description) values(?,?,?,?)", row.Year, row.QuarterType, row.MedianMonthlyRent, row.Description) 
cnxn.commit()
cursor.close()

# %%
df7b = xl.parse("E107be")

# %%
df7b = df7b.iloc[3:11,:4]

# %%
df7b
# Out:
#    Table E107b : Median Rent to Income Ratio by Type of Quarters and Year  \
# 3                                                Year
# 4                                    Type of Quarters
# 5                         Public rental housing units
# 6                           Private residential flats
# 7         Other quarters in private permanent housing
# 8    Permanent quarters in other types of housing (2)
# 9                              Temporary quarters (3)
# 10                                            Overall
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3
# 3        2011      2016.0      2021.0
# 4         NaN         NaN         NaN
# 5        10.6         9.3        11.7
# 6        25.7        30.7        31.4
# 7        15.8        20.6        23.8
# 8        20.6        31.1        24.8
# 9        19.4        23.4        22.9
# 10       13.9        13.6        16.8

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df7b.iloc[0, 1:]):
    for inner_idx, quarterType in enumerate(df7b.iloc[2:,0]):
        new_row = [int(year), re.sub(r'\([^)]*\)', '', str(quarterType)), df7b.iloc[inner_idx+2,idx+1], "Ratio expressed in percentage"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
columns7b = ["Year", "QuarterType", "MedianRentToIncomeRatio", "Description"]

# %%
result_df.columns = columns7b

# %%
result_df
# Out:
#     Year                                    QuarterType  \
# 0   2011                    Public rental housing units
# 1   2011                      Private residential flats
# 2   2011    Other quarters in private permanent housing
# 3   2011  Permanent quarters in other types of housing
# 4   2011                            Temporary quarters
# 5   2011                                        Overall
# 6   2016                    Public rental housing units
# 7   2016                      Private residential flats
# 8   2016    Other quarters in private permanent housing
# 9   2016  Permanent quarters in other types of housing
# 10  2016                            Temporary quarters
# 11  2016                                        Overall
# 12  2021                    Public rental housing units
# 13  2021                      Private residential flats
# 14  2021    Other quarters in private permanent housing
# 15  2021  Permanent quarters in other types of housing
# 16  2021                            Temporary quarters
# 17  2021                                        Overall
#
#     MedianRentToIncomeRatio                    Description
# 0                      10.6  Ratio expressed in percentage
# 1                      25.7  Ratio expressed in percentage
# 2                      15.8  Ratio expressed in percentage
# 3                      20.6  Ratio expressed in percentage
# 4                      19.4  Ratio expressed in percentage
# 5                      13.9  Ratio expressed in percentage
# 6                       9.3  Ratio expressed in percentage
# 7                      30.7  Ratio expressed in percentage
# 8                      20.6  Ratio expressed in percentage
# 9                      31.1  Ratio expressed in percentage
# 10                     23.4  Ratio expressed in percentage
# 11                     13.6  Ratio expressed in percentage
# 12                     11.7  Ratio expressed in percentage
# 13                     31.4  Ratio expressed in percentage
# 14                     23.8  Ratio expressed in percentage
# 15                     24.8  Ratio expressed in percentage
# 16                     22.9  Ratio expressed in percentage
# 17                     16.8  Ratio expressed in percentage

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.MedianRentToIncomeRatio (Year, QuarterType, MedianRentToIncomeRatio, Description) values(?,?,?,?)", row.Year, row.QuarterType, row.MedianRentToIncomeRatio, row.Description) 
cnxn.commit()
cursor.close()

# %%
columns8a = ["Year", "HousingType", "NumberOfRooms", "HouseholdsNumber", "HouseholdsPercentage", "Description"]

# %%
df8a = xl.parse("E108ae")

# %%
df8a = df8a.iloc[1:15,:12]

# %%
df8a.iloc[12,1] = 0

# %%
df8a.iloc[13,1] = "Total"

# %%
df8a.iloc[12,7] = 0.05

# %%
df8a
# Out:
#    Table E108a : Domestic Households (Excluding those Living on Board Vessels) by Number of Rooms, Year and Type of Housing  \
# 1                                                Year
# 2                                     Type of Housing
# 3                                                 NaN
# 4                                                 NaN
# 5   Number of Rooms - With/ Without Exclusively Us...
# 6                     With exclusively used rooms (2)
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                 Without exclusively used rooms (2)
# 14                                              Total
#
#          Unnamed: 1                                         Unnamed: 2  \
# 1               NaN                                               2021
# 2               NaN                              Public rental housing
# 3               NaN  Domestic Households (Excluding those Living on...
# 4               NaN                                             Number
# 5   Number of Rooms                                                NaN
# 6                 1                                             190171
# 7                 2                                             201505
# 8                 3                                             315339
# 9                 4                                              88694
# 10                5                                               9557
# 11               6+                                               2038
# 12        Sub-Total                                             807304
# 13                0                                                 --
# 14            Total                                             807304
#
#     Unnamed: 3                                         Unnamed: 4  Unnamed: 5  \
# 1          NaN                                                NaN         NaN
# 2          NaN                  Subsidised home ownership housing         NaN
# 3          NaN  Domestic Households (Excluding those Living on...         NaN
# 4   Percentage                                             Number  Percentage
# 5          NaN                                                NaN         NaN
# 6          7.1                                              10229         0.4
# 7          7.5                                              37191         1.4
# 8         11.8                                             198972         7.4
# 9          3.3                                             124809         4.7
# 10         0.4                                              39201         1.5
# 11         0.1                                               3386         0.1
# 12        30.2                                             413788        15.5
# 13          --                                                 --          --
# 14        30.2                                             413788        15.5
#
#                                            Unnamed: 6  Unnamed: 7  \
# 1                                                 NaN         NaN
# 2                           Private permanent housing         NaN
# 3   Domestic Households (Excluding those Living on...         NaN
# 4                                              Number  Percentage
# 5                                                 NaN         NaN
# 6                                               57088         2.1
# 7                                              176374         6.6
# 8                                              511941        19.1
# 9                                              382736        14.3
# 10                                             190707         7.1
# 11                                              96410         3.6
# 12                                            1415256        52.9
# 13                                                484        0.05
# 14                                            1415740          53
#
#                                            Unnamed: 8  Unnamed: 9  \
# 1                                                 NaN         NaN
# 2                                              Others         NaN
# 3   Domestic Households (Excluding those Living on...         NaN
# 4                                              Number  Percentage
# 5                                                 NaN         NaN
# 6                                                5682         0.2
# 7                                                8236         0.3
# 8                                                9844         0.4
# 9                                                5369         0.2
# 10                                               3356         0.1
# 11                                               2703         0.1
# 12                                              35190         1.3
# 13                                               1692         0.1
# 14                                              36882         1.4
#
#                                           Unnamed: 10 Unnamed: 11
# 1                                                 NaN         NaN
# 2                                               Total         NaN
# 3   Domestic Households (Excluding those Living on...         NaN
# 4                                              Number  Percentage
# 5                                                 NaN         NaN
# 6                                              263170         9.8
# 7                                              423306        15.8
# 8                                             1036096        38.8
# 9                                              601608        22.5
# 10                                             242821         9.1
# 11                                             104537         3.9
# 12                                            2671538        99.9
# 13                                               2176         0.1
# 14                                            2673714         100

# %%
def toZeroOrFloat(value):
    if (str(value) == "--"):
        return 0
    else:
        return float(value)

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df8a.iloc[1, 2:].dropna()):
    for inner_idx, numberOfRooms in enumerate(df8a.iloc[6:,1]):
        new_row = ["2021", housingType, numberOfRooms, toZeroOrFloat(df8a.iloc[6+inner_idx, idx*2 + 2]), toZeroOrFloat(df8a.iloc[6+inner_idx, idx*2 + 3]), "Household excludes those living on board vessels"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
columns8a = ["Year", "HousingType", "NumberOfRooms", "NumberOfHouseholds", "PercentageOfHouseholds", "Description"]

# %%
result_df.columns = columns8a

# %%
result_df
# Out:
#     Year                        HousingType NumberOfRooms  NumberOfHouseholds  \
# 0   2021              Public rental housing             2            201505.0
# 1   2021              Public rental housing             3            315339.0
# 2   2021              Public rental housing             4             88694.0
# 3   2021              Public rental housing             5              9557.0
# 4   2021              Public rental housing            6+              2038.0
# 5   2021              Public rental housing     Sub-Total            807304.0
# 6   2021              Public rental housing             0                 0.0
# 7   2021              Public rental housing         Total            807304.0
# 8   2021  Subsidised home ownership housing             2             37191.0
# 9   2021  Subsidised home ownership housing             3            198972.0
# 10  2021  Subsidised home ownership housing             4            124809.0
# 11  2021  Subsidised home ownership housing             5             39201.0
# 12  2021  Subsidised home ownership housing            6+              3386.0
# 13  2021  Subsidised home ownership housing     Sub-Total            413788.0
# 14  2021  Subsidised home ownership housing             0                 0.0
# 15  2021  Subsidised home ownership housing         Total            413788.0
# 16  2021          Private permanent housing             2            176374.0
# 17  2021          Private permanent housing             3            511941.0
# 18  2021          Private permanent housing             4            382736.0
# 19  2021          Private permanent housing             5            190707.0
# 20  2021          Private permanent housing            6+             96410.0
# 21  2021          Private permanent housing     Sub-Total           1415256.0
# 22  2021          Private permanent housing             0               484.0
# 23  2021          Private permanent housing         Total           1415740.0
# 24  2021                             Others             2              8236.0
# 25  2021                             Others             3              9844.0
# 26  2021                             Others             4              5369.0
# 27  2021                             Others             5              3356.0
# 28  2021                             Others            6+              2703.0
# 29  2021                             Others     Sub-Total             35190.0
# 30  2021                             Others             0              1692.0
# 31  2021                             Others         Total             36882.0
# 32  2021                              Total             2            423306.0
# 33  2021                              Total             3           1036096.0
# 34  2021                              Total             4            601608.0
# 35  2021                              Total             5            242821.0
# 36  2021                              Total            6+            104537.0
# 37  2021                              Total     Sub-Total           2671538.0
# 38  2021                              Total             0              2176.0
# 39  2021                              Total         Total           2673714.0
#
#     PercentageOfHouseholds                                       Description
# 0                     7.50  Household excludes those living on board vessels
# 1                    11.80  Household excludes those living on board vessels
# 2                     3.30  Household excludes those living on board vessels
# 3                     0.40  Household excludes those living on board vessels
# 4                     0.10  Household excludes those living on board vessels
# 5                    30.20  Household excludes those living on board vessels
# 6                     0.00  Household excludes those living on board vessels
# 7                    30.20  Household excludes those living on board vessels
# 8                     1.40  Household excludes those living on board vessels
# 9                     7.40  Household excludes those living on board vessels
# 10                    4.70  Household excludes those living on board vessels
# 11                    1.50  Household excludes those living on board vessels
# 12                    0.10  Household excludes those living on board vessels
# 13                   15.50  Household excludes those living on board vessels
# 14                    0.00  Household excludes those living on board vessels
# 15                   15.50  Household excludes those living on board vessels
# 16                    6.60  Household excludes those living on board vessels
# 17                   19.10  Household excludes those living on board vessels
# 18                   14.30  Household excludes those living on board vessels
# 19                    7.10  Household excludes those living on board vessels
# 20                    3.60  Household excludes those living on board vessels
# 21                   52.90  Household excludes those living on board vessels
# 22                    0.05  Household excludes those living on board vessels
# 23                   53.00  Household excludes those living on board vessels
# 24                    0.30  Household excludes those living on board vessels
# 25                    0.40  Household excludes those living on board vessels
# 26                    0.20  Household excludes those living on board vessels
# 27                    0.10  Household excludes those living on board vessels
# 28                    0.10  Household excludes those living on board vessels
# 29                    1.30  Household excludes those living on board vessels
# 30                    0.10  Household excludes those living on board vessels
# 31                    1.40  Household excludes those living on board vessels
# 32                   15.80  Household excludes those living on board vessels
# 33                   38.80  Household excludes those living on board vessels
# 34                   22.50  Household excludes those living on board vessels
# 35                    9.10  Household excludes those living on board vessels
# 36                    3.90  Household excludes those living on board vessels
# 37                   99.90  Household excludes those living on board vessels
# 38                    0.10  Household excludes those living on board vessels
# 39                  100.00  Household excludes those living on board vessels

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdByHousingTypeAndNumberOfRooms (Year, HousingType, NumberOfRooms, NumberOfHouseholds, PercentageOfHouseholds, Description) values(?,?,?,?,?,?)", row.Year, row.HousingType, row.NumberOfRooms, row.NumberOfHouseholds, row.PercentageOfHouseholds, row.Description) 
cnxn.commit()
cursor.close()

# %%
df8b = xl.parse("E108be")

# %%
df8b = df8b.iloc[2:5,:7]

# %%
df8b
# Out:
#   Table E108b : Average Number of Rooms by Year and Type of Housing  \
# 2                                    Type of Housing
# 3                        Average Number of Rooms (1)
# 4                                                NaN
#
#                                Unnamed: 1             Unnamed: 2  \
# 2                                     NaN  Public rental housing
# 3  Number of Rooms Per Domestic Household                    2.4
# 4              Number of Rooms Per Person                    0.9
#
#                           Unnamed: 3                 Unnamed: 4 Unnamed: 5  \
# 2  Subsidised home ownership housing  Private permanent housing     Others
# 3                                3.4                        3.6        2.9
# 4                                1.2                        1.3        1.2
#
#   Unnamed: 6
# 2    Overall
# 3        3.2
# 4        1.2

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df8b.iloc[0,2:]):
    new_row = [2021, housingType, df8b.iloc[1,idx+2], df8b.iloc[2,idx+2]]
    result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "NumberOfRoomsPerHousehold", "NumberOfRoomsPerPerson"]

# %%
result_df
# Out:
#    Year                        HousingType  NumberOfRoomsPerHousehold  \
# 0  2021              Public rental housing                        2.4
# 1  2021  Subsidised home ownership housing                        3.4
# 2  2021          Private permanent housing                        3.6
# 3  2021                             Others                        2.9
# 4  2021                            Overall                        3.2
#
#    NumberOfRoomsPerPerson
# 0                     0.9
# 1                     1.2
# 2                     1.3
# 3                     1.2
# 4                     1.2

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.NumberOfRoomsByHousingType (Year, HousingType, NumberOfRoomsPerHousehold, NumberOfRoomsPerPerson) values(?,?,?,?)", row.Year, row.HousingType, row.NumberOfRoomsPerHousehold, row.NumberOfRoomsPerPerson) 
cnxn.commit()
cursor.close()

# %%
df9 = xl.parse("E109e")

# %%
df9 = df9.iloc[4:20,:-2]

# %%
df9
# Out:
#    Table E109 : Domestic Households by Monthly Domestic Household Mortgage Payment and Loan Repayment (HK$), Year and Type of Housing  \
# 4                                     Type of Housing
# 5   Monthly Domestic Household Mortgage Payment an...
# 6                       By non-household members only
# 7                                           1 - 1,999
# 8                                       2,000 - 3,999
# 9                                       4,000 - 5,999
# 10                                      6,000 - 7,999
# 11                                      8,000 - 9,999
# 12                                    10,000 - 14,999
# 13                                    15,000 - 19,999
# 14                                    20,000 - 24,999
# 15                                    25,000 - 29,999
# 16                                    30,000 - 39,999
# 17                                    40,000 and over
# 18  Not required to pay mortgage payment and loan ...
# 19                                              Total
#
#                Unnamed: 1                         Unnamed: 2  \
# 4   Public rental housing  Subsidised home ownership housing
# 5                     NaN                                NaN
# 6                      --                               9544
# 7                      --                               5468
# 8                      --                              11706
# 9                      --                              11281
# 10                     --                              10261
# 11                     --                               7961
# 12                     --                              14141
# 13                     --                               4186
# 14                     --                               1497
# 15                     --                                466
# 16                     --                                269
# 17                     --                                108
# 18                 807304                             336900
# 19                 807304                             413788
#
#                    Unnamed: 3            Unnamed: 4         Unnamed: 5  \
# 4   Private permanent housing  Non-domestic housing  Temporary housing
# 5                         NaN                   NaN                NaN
# 6                       39169                    --                 --
# 7                        4263                    --                 --
# 8                        9645                    --                 --
# 9                       23048                    --                 --
# 10                      28175                    --                 --
# 11                      29989                    --                 --
# 12                      85566                    --                 --
# 13                      63132                    --                 --
# 14                      35052                    --                 --
# 15                      15956                    --                 --
# 16                      14268                    --                 --
# 17                      15009                    --                 --
# 18                    1052468                 13134              24195
# 19                    1415740                 13134              24195
#
#    Unnamed: 6
# 4       Total
# 5         NaN
# 6       48713
# 7        9731
# 8       21351
# 9       34329
# 10      38436
# 11      37950
# 12      99707
# 13      67318
# 14      36549
# 15      16422
# 16      14537
# 17      15117
# 18    2234001
# 19    2674161

# %%
def toEmptyOrFloat(value):
    if (str(value) == "--"):
        pass
    else:
        return float(value)

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df9.iloc[0,1:]):
    for inner_idx, mortage_range in enumerate(df9.iloc[7:19,0]):
        new_row = [2021, housingType, mortage_range, df9.iloc[inner_idx+7,idx+1], "Mortage payment range in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "MortagePaymentRange", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#     Year                        HousingType  \
# 0   2021              Public rental housing
# 1   2021              Public rental housing
# 2   2021              Public rental housing
# 3   2021              Public rental housing
# 4   2021              Public rental housing
# 5   2021              Public rental housing
# 6   2021              Public rental housing
# 7   2021              Public rental housing
# 8   2021              Public rental housing
# 9   2021  Subsidised home ownership housing
# 10  2021  Subsidised home ownership housing
# 11  2021  Subsidised home ownership housing
# 12  2021  Subsidised home ownership housing
# 13  2021  Subsidised home ownership housing
# 14  2021  Subsidised home ownership housing
# 15  2021  Subsidised home ownership housing
# 16  2021  Subsidised home ownership housing
# 17  2021  Subsidised home ownership housing
# 18  2021          Private permanent housing
# 19  2021          Private permanent housing
# 20  2021          Private permanent housing
# 21  2021          Private permanent housing
# 22  2021          Private permanent housing
# 23  2021          Private permanent housing
# 24  2021          Private permanent housing
# 25  2021          Private permanent housing
# 26  2021          Private permanent housing
# 27  2021               Non-domestic housing
# 28  2021               Non-domestic housing
# 29  2021               Non-domestic housing
# 30  2021               Non-domestic housing
# 31  2021               Non-domestic housing
# 32  2021               Non-domestic housing
# 33  2021               Non-domestic housing
# 34  2021               Non-domestic housing
# 35  2021               Non-domestic housing
# 36  2021                  Temporary housing
# 37  2021                  Temporary housing
# 38  2021                  Temporary housing
# 39  2021                  Temporary housing
# 40  2021                  Temporary housing
# 41  2021                  Temporary housing
# 42  2021                  Temporary housing
# 43  2021                  Temporary housing
# 44  2021                  Temporary housing
# 45  2021                              Total
# 46  2021                              Total
# 47  2021                              Total
# 48  2021                              Total
# 49  2021                              Total
# 50  2021                              Total
# 51  2021                              Total
# 52  2021                              Total
# 53  2021                              Total
#
#                                   MortagePaymentRange NumberOfHouseholds  \
# 0                                       8,000 - 9,999                 --
# 1                                     10,000 - 14,999                 --
# 2                                     15,000 - 19,999                 --
# 3                                     20,000 - 24,999                 --
# 4                                     25,000 - 29,999                 --
# 5                                     30,000 - 39,999                 --
# 6                                     40,000 and over                 --
# 7   Not required to pay mortgage payment and loan ...             807304
# 8                                               Total             807304
# 9                                       8,000 - 9,999               7961
# 10                                    10,000 - 14,999              14141
# 11                                    15,000 - 19,999               4186
# 12                                    20,000 - 24,999               1497
# 13                                    25,000 - 29,999                466
# 14                                    30,000 - 39,999                269
# 15                                    40,000 and over                108
# 16  Not required to pay mortgage payment and loan ...             336900
# 17                                              Total             413788
# 18                                      8,000 - 9,999              29989
# 19                                    10,000 - 14,999              85566
# 20                                    15,000 - 19,999              63132
# 21                                    20,000 - 24,999              35052
# 22                                    25,000 - 29,999              15956
# 23                                    30,000 - 39,999              14268
# 24                                    40,000 and over              15009
# 25  Not required to pay mortgage payment and loan ...            1052468
# 26                                              Total            1415740
# 27                                      8,000 - 9,999                 --
# 28                                    10,000 - 14,999                 --
# 29                                    15,000 - 19,999                 --
# 30                                    20,000 - 24,999                 --
# 31                                    25,000 - 29,999                 --
# 32                                    30,000 - 39,999                 --
# 33                                    40,000 and over                 --
# 34  Not required to pay mortgage payment and loan ...              13134
# 35                                              Total              13134
# 36                                      8,000 - 9,999                 --
# 37                                    10,000 - 14,999                 --
# 38                                    15,000 - 19,999                 --
# 39                                    20,000 - 24,999                 --
# 40                                    25,000 - 29,999                 --
# 41                                    30,000 - 39,999                 --
# 42                                    40,000 and over                 --
# 43  Not required to pay mortgage payment and loan ...              24195
# 44                                              Total              24195
# 45                                      8,000 - 9,999              37950
# 46                                    10,000 - 14,999              99707
# 47                                    15,000 - 19,999              67318
# 48                                    20,000 - 24,999              36549
# 49                                    25,000 - 29,999              16422
# 50                                    30,000 - 39,999              14537
# 51                                    40,000 and over              15117
# 52  Not required to pay mortgage payment and loan ...            2234001
# 53                                              Total            2674161
#
#                      Description
# 0   Mortage payment range in HK$
# 1   Mortage payment range in HK$
# 2   Mortage payment range in HK$
# 3   Mortage payment range in HK$
# 4   Mortage payment range in HK$
# 5   Mortage payment range in HK$
# 6   Mortage payment range in HK$
# 7   Mortage payment range in HK$
# 8   Mortage payment range in HK$
# 9   Mortage payment range in HK$
# 10  Mortage payment range in HK$
# 11  Mortage payment range in HK$
# 12  Mortage payment range in HK$
# 13  Mortage payment range in HK$
# 14  Mortage payment range in HK$
# 15  Mortage payment range in HK$
# 16  Mortage payment range in HK$
# 17  Mortage payment range in HK$
# 18  Mortage payment range in HK$
# 19  Mortage payment range in HK$
# 20  Mortage payment range in HK$
# 21  Mortage payment range in HK$
# 22  Mortage payment range in HK$
# 23  Mortage payment range in HK$
# 24  Mortage payment range in HK$
# 25  Mortage payment range in HK$
# 26  Mortage payment range in HK$
# 27  Mortage payment range in HK$
# 28  Mortage payment range in HK$
# 29  Mortage payment range in HK$
# 30  Mortage payment range in HK$
# 31  Mortage payment range in HK$
# 32  Mortage payment range in HK$
# 33  Mortage payment range in HK$
# 34  Mortage payment range in HK$
# 35  Mortage payment range in HK$
# 36  Mortage payment range in HK$
# 37  Mortage payment range in HK$
# 38  Mortage payment range in HK$
# 39  Mortage payment range in HK$
# 40  Mortage payment range in HK$
# 41  Mortage payment range in HK$
# 42  Mortage payment range in HK$
# 43  Mortage payment range in HK$
# 44  Mortage payment range in HK$
# 45  Mortage payment range in HK$
# 46  Mortage payment range in HK$
# 47  Mortage payment range in HK$
# 48  Mortage payment range in HK$
# 49  Mortage payment range in HK$
# 50  Mortage payment range in HK$
# 51  Mortage payment range in HK$
# 52  Mortage payment range in HK$
# 53  Mortage payment range in HK$

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdByHousingTypeAndMortagePaymentRange (Year, HousingType, MortagePaymentRange, NumberOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.HousingType, row.MortagePaymentRange, toEmptyOrFloat(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df10 = xl.parse("E110e")

# %%
df10 = df10.iloc[3:23,:-2]

# %%
df10
# Out:
#    Table E110 : Domestic Households by Monthly Domestic Household Rent (HK$), Year and Type of Housing  \
# 3                                                Year
# 4                                     Type of Housing
# 5               Monthly Domestic Household Rent (HK$)
# 6                                               0 (1)
# 7                                             1 - 499
# 8                                           500 - 999
# 9                                       1,000 - 1,499
# 10                                      1,500 - 1,999
# 11                                      2,000 - 3,999
# 12                                      4,000 - 5,999
# 13                                      6,000 - 7,999
# 14                                      8,000 - 9,999
# 15                                    10,000 - 14,999
# 16                                    15,000 - 19,999
# 17                                    20,000 - 24,999
# 18                                    25,000 - 29,999
# 19                                    30,000 - 39,999
# 20                                    40,000 and over
# 21                       Not required to pay rent (2)
# 22                                              Total
#
#                Unnamed: 1                         Unnamed: 2  \
# 3                    2021                                NaN
# 4   Public rental housing  Subsidised home ownership housing
# 5                     NaN                                NaN
# 6                      --                                 --
# 7                    2389                                105
# 8                   23559                                270
# 9                  143311                                476
# 10                 179146                                495
# 11                 410734                                990
# 12                  46200                                323
# 13                   1760                                497
# 14                    185                                753
# 15                     20                               1284
# 16                     --                                300
# 17                     --                                 46
# 18                     --                                 --
# 19                     --                                 --
# 20                     --                                 --
# 21                     --                             408249
# 22                 807304                             413788
#
#                    Unnamed: 3            Unnamed: 4         Unnamed: 5  \
# 3                         NaN                   NaN                NaN
# 4   Private permanent housing  Non-domestic housing  Temporary housing
# 5                         NaN                   NaN                NaN
# 6                        3260                  1725                 26
# 7                        1568                    34                181
# 8                        1816                   305                268
# 9                        3724                   499                521
# 10                      10015                   729                888
# 11                      40986                  1282               4306
# 12                      63786                  1013               2903
# 13                      44146                   704               1127
# 14                      37105                  1156                411
# 15                     109151                   807                428
# 16                      65622                  1362                148
# 17                      34080                   794                 --
# 18                      16671                   237                 10
# 19                      18753                    95                  8
# 20                      24010                   565                 --
# 21                     941047                  1827              12970
# 22                    1415740                 13134              24195
#
#    Unnamed: 6
# 3         NaN
# 4       Total
# 5         NaN
# 6        5011
# 7        4277
# 8       26218
# 9      148531
# 10     191273
# 11     458298
# 12     114225
# 13      48234
# 14      39610
# 15     111690
# 16      67432
# 17      34920
# 18      16918
# 19      18856
# 20      24575
# 21    1364093
# 22    2674161

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df10.iloc[1,1:]):
    for inner_idx, mortageRange in enumerate(df10.iloc[3:,0]):
        new_row = [2021, housingType, re.sub(r'\([^)]*\)', '', mortageRange), df10.iloc[inner_idx+3, idx+1], "Rent expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "MonthlyRentRange", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#      Year            HousingType           MonthlyRentRange  \
# 0    2021  Public rental housing                         0
# 1    2021  Public rental housing                    1 - 499
# 2    2021  Public rental housing                  500 - 999
# 3    2021  Public rental housing              1,000 - 1,499
# 4    2021  Public rental housing              1,500 - 1,999
# ..    ...                    ...                        ...
# 97   2021                  Total            25,000 - 29,999
# 98   2021                  Total            30,000 - 39,999
# 99   2021                  Total            40,000 and over
# 100  2021                  Total  Not required to pay rent
# 101  2021                  Total                      Total
#
#     NumberOfHouseholds            Description
# 0                   --  Rent expressed in HK$
# 1                 2389  Rent expressed in HK$
# 2                23559  Rent expressed in HK$
# 3               143311  Rent expressed in HK$
# 4               179146  Rent expressed in HK$
# ..                 ...                    ...
# 97               16918  Rent expressed in HK$
# 98               18856  Rent expressed in HK$
# 99               24575  Rent expressed in HK$
# 100            1364093  Rent expressed in HK$
# 101            2674161  Rent expressed in HK$
#
# [102 rows x 5 columns]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdByHousingTypeAndMonthlyRentRange (Year, HousingType, MonthlyRentRange, NumberOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.HousingType, row.MonthlyRentRange, toEmptyOrFloat(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df11a = xl.parse("E111ae")

# %%
df11a = df11a.iloc[3:111,:-2]

# %%
df11a = df11a.fillna(method="ffill")
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_23760\1764181186.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df11a = df11a.fillna(method="ffill")

# %%
df11a
# Out:
#     Table E111a : Domestic Households by Household Size, Monthly Domestic Household Income (HK$), Year and Type of Housing  \
# 3                                                 Year
# 4                                      Type of Housing
# 5                                       Household Size
# 6                                                    1
# 7                                                    1
# ..                                                 ...
# 106                                              Total
# 107                                              Total
# 108                                              Total
# 109                                              Total
# 110                                              Total
#
#                                   Unnamed: 1             Unnamed: 2  \
# 3                                        NaN                   2021
# 4                                        NaN  Public rental housing
# 5    Monthly Domestic Household Income (HK$)  Public rental housing
# 6                            Less than 2,000                   8245
# 7                              2,000 - 3,999                  14856
# ..                                       ...                    ...
# 106                          40,000 - 59,999                  93865
# 107                          60,000 - 79,999                  26623
# 108                          80,000 - 99,999                   7048
# 109                         100,000 and over                   2107
# 110                                    Total                 807304
#
#                             Unnamed: 3                 Unnamed: 4  \
# 3                                  NaN                        NaN
# 4    Subsidised home ownership housing  Private permanent housing
# 5    Subsidised home ownership housing  Private permanent housing
# 6                                 9084                      35112
# 7                                 5508                      10847
# ..                                 ...                        ...
# 106                              77477                     223186
# 107                              34421                     148172
# 108                              15147                      91629
# 109                              10293                     219261
# 110                             413788                    1415740
#
#                Unnamed: 5         Unnamed: 6 Unnamed: 7
# 3                     NaN                NaN        NaN
# 4    Non-domestic housing  Temporary housing      Total
# 5    Non-domestic housing  Temporary housing      Total
# 6                     914               2330      55685
# 7                     386                704      32301
# ..                    ...                ...        ...
# 106                  1798               3002     399328
# 107                  1085               1020     211321
# 108                   850                204     114878
# 109                  1629                335     233625
# 110                 13134              24195    2674161
#
# [108 rows x 8 columns]

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df11a.iloc[1,2:]):
    for inner_idx, monthlyIncome in enumerate(df11a.iloc[3:18,1]):
        for third_idx, householdSize in enumerate(df11a.iloc[3:,0].drop_duplicates()):
            new_row = [2021, housingType, df11a.iloc[3+third_idx*15,0], monthlyIncome, df11a.iloc[3+third_idx*15+inner_idx, idx+2], "Monthly Household Income Range expressed in HK$"]
            result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.iloc[629,3] = "Total"

# %%
result_df.columns = ["Year", "HousingType", "HouseholdSize", "MonthlyHouseholdIncomeRange", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#      Year            HousingType HouseholdSize MonthlyHouseholdIncomeRange  \
# 0    2021  Public rental housing             1             Less than 2,000
# 1    2021  Public rental housing             2             Less than 2,000
# 2    2021  Public rental housing             3             Less than 2,000
# 3    2021  Public rental housing             4             Less than 2,000
# 4    2021  Public rental housing             5             Less than 2,000
# ..    ...                    ...           ...                         ...
# 625  2021                  Total             3                   Sub-Total
# 626  2021                  Total             4                   Sub-Total
# 627  2021                  Total             5                   Sub-Total
# 628  2021                  Total    6 and over                   Sub-Total
# 629  2021                  Total         Total                       Total
#
#     NumberOfHouseholds                                      Description
# 0                 8245  Monthly Household Income Range expressed in HK$
# 1                10165  Monthly Household Income Range expressed in HK$
# 2                 4011  Monthly Household Income Range expressed in HK$
# 3                 1990  Monthly Household Income Range expressed in HK$
# 4                  521  Monthly Household Income Range expressed in HK$
# ..                 ...                                              ...
# 625             641187  Monthly Household Income Range expressed in HK$
# 626             456067  Monthly Household Income Range expressed in HK$
# 627             191927  Monthly Household Income Range expressed in HK$
# 628              77196  Monthly Household Income Range expressed in HK$
# 629            2674161  Monthly Household Income Range expressed in HK$
#
# [630 rows x 6 columns]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdByHousingTypeAndHouseholdSizeAndMonthlyHouseholdIncomeRange (Year, HousingType, HouseholdSize, MonthlyHouseholdIncomeRange, NumberOfHouseholds, Description) values(?,?,?,?,?,?)", row.Year, row.HousingType, row.HouseholdSize, row.MonthlyHouseholdIncomeRange, toEmptyOrFloat(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df11b = xl.parse("E111be")

# %%
df11b = df11b.iloc[1:13,:-2]

# %%
df11b
# Out:
#    Table E111b : Median Monthly Domestic Household Income by Household Size, Year and Type of Housing  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4                                     Type of Housing
# 5                                      Household Size
# 6                                                   1
# 7                                                   2
# 8                                                   3
# 9                                                   4
# 10                                                  5
# 11                                         6 and over
# 12                                            Overall
#
#                                   Unnamed: 1  \
# 1   Median Monthly Domestic Household Income
# 2                                        HK$
# 3                                       2021
# 4                      Public rental housing
# 5                                        NaN
# 6                                       6380
# 7                                      13920
# 8                                      24880
# 9                                      32030
# 10                                     35480
# 11                                     40310
# 12                                     18500
#
#                            Unnamed: 2                 Unnamed: 3  \
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4   Subsidised home ownership housing  Private permanent housing
# 5                                 NaN                        NaN
# 6                                8820                      16540
# 7                               18040                      29390
# 8                               33150                      40070
# 9                               44410                      57230
# 10                              50700                      78610
# 11                              55070                      87300
# 12                              28040                      37470
#
#               Unnamed: 4         Unnamed: 5 Unnamed: 6
# 1                    NaN                NaN        NaN
# 2                    NaN                NaN        NaN
# 3                    NaN                NaN        NaN
# 4   Non-domestic housing  Temporary housing    Overall
# 5                    NaN                NaN        NaN
# 6                  14300               4690      10100
# 7                  37240              13810      20000
# 8                  34300              22770      32040
# 9                  42090              32000      44230
# 10                 56210              31490      56690
# 11                 79040              45610      60110
# 12                 26480              16810      27650

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df11b.iloc[3,1:]):
    for inner_idx, householdSize in enumerate(df11b.iloc[5:,0]):
        new_row = [2021, housingType, householdSize, df11b.iloc[inner_idx+5,idx+1], "Monthly household income expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "HouseholdSize", "MedianMonthlyHouseholdIncome", "Description"]

# %%
result_df
# Out:
#     Year                        HousingType HouseholdSize  \
# 0   2021              Public rental housing             1
# 1   2021              Public rental housing             2
# 2   2021              Public rental housing             3
# 3   2021              Public rental housing             4
# 4   2021              Public rental housing             5
# 5   2021              Public rental housing    6 and over
# 6   2021              Public rental housing       Overall
# 7   2021  Subsidised home ownership housing             1
# 8   2021  Subsidised home ownership housing             2
# 9   2021  Subsidised home ownership housing             3
# 10  2021  Subsidised home ownership housing             4
# 11  2021  Subsidised home ownership housing             5
# 12  2021  Subsidised home ownership housing    6 and over
# 13  2021  Subsidised home ownership housing       Overall
# 14  2021          Private permanent housing             1
# 15  2021          Private permanent housing             2
# 16  2021          Private permanent housing             3
# 17  2021          Private permanent housing             4
# 18  2021          Private permanent housing             5
# 19  2021          Private permanent housing    6 and over
# 20  2021          Private permanent housing       Overall
# 21  2021               Non-domestic housing             1
# 22  2021               Non-domestic housing             2
# 23  2021               Non-domestic housing             3
# 24  2021               Non-domestic housing             4
# 25  2021               Non-domestic housing             5
# 26  2021               Non-domestic housing    6 and over
# 27  2021               Non-domestic housing       Overall
# 28  2021                  Temporary housing             1
# 29  2021                  Temporary housing             2
# 30  2021                  Temporary housing             3
# 31  2021                  Temporary housing             4
# 32  2021                  Temporary housing             5
# 33  2021                  Temporary housing    6 and over
# 34  2021                  Temporary housing       Overall
# 35  2021                            Overall             1
# 36  2021                            Overall             2
# 37  2021                            Overall             3
# 38  2021                            Overall             4
# 39  2021                            Overall             5
# 40  2021                            Overall    6 and over
# 41  2021                            Overall       Overall
#
#     MedianMonthlyHouseholdIncome                                Description
# 0                           6380  Monthly household income expressed in HK$
# 1                          13920  Monthly household income expressed in HK$
# 2                          24880  Monthly household income expressed in HK$
# 3                          32030  Monthly household income expressed in HK$
# 4                          35480  Monthly household income expressed in HK$
# 5                          40310  Monthly household income expressed in HK$
# 6                          18500  Monthly household income expressed in HK$
# 7                           8820  Monthly household income expressed in HK$
# 8                          18040  Monthly household income expressed in HK$
# 9                          33150  Monthly household income expressed in HK$
# 10                         44410  Monthly household income expressed in HK$
# 11                         50700  Monthly household income expressed in HK$
# 12                         55070  Monthly household income expressed in HK$
# 13                         28040  Monthly household income expressed in HK$
# 14                         16540  Monthly household income expressed in HK$
# 15                         29390  Monthly household income expressed in HK$
# 16                         40070  Monthly household income expressed in HK$
# 17                         57230  Monthly household income expressed in HK$
# 18                         78610  Monthly household income expressed in HK$
# 19                         87300  Monthly household income expressed in HK$
# 20                         37470  Monthly household income expressed in HK$
# 21                         14300  Monthly household income expressed in HK$
# 22                         37240  Monthly household income expressed in HK$
# 23                         34300  Monthly household income expressed in HK$
# 24                         42090  Monthly household income expressed in HK$
# 25                         56210  Monthly household income expressed in HK$
# 26                         79040  Monthly household income expressed in HK$
# 27                         26480  Monthly household income expressed in HK$
# 28                          4690  Monthly household income expressed in HK$
# 29                         13810  Monthly household income expressed in HK$
# 30                         22770  Monthly household income expressed in HK$
# 31                         32000  Monthly household income expressed in HK$
# 32                         31490  Monthly household income expressed in HK$
# 33                         45610  Monthly household income expressed in HK$
# 34                         16810  Monthly household income expressed in HK$
# 35                         10100  Monthly household income expressed in HK$
# 36                         20000  Monthly household income expressed in HK$
# 37                         32040  Monthly household income expressed in HK$
# 38                         44230  Monthly household income expressed in HK$
# 39                         56690  Monthly household income expressed in HK$
# 40                         60110  Monthly household income expressed in HK$
# 41                         27650  Monthly household income expressed in HK$

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdIncomeByHousingTypeAndHouseholdSize (Year, HousingType, HouseholdSize, MedianMonthlyHouseholdIncome, Description) values(?,?,?,?,?)", row.Year, row.HousingType, row.HouseholdSize, row.MedianMonthlyHouseholdIncome, row.Description) 
cnxn.commit()
cursor.close()

# %%
df11c = xl.parse("E111ce")

# %%
df11c = df11c.iloc[1:111, :-2]

# %%
df11c
# Out:
#     Table E111c : Economically Active Domestic Households by Household Size, Monthly Domestic Household Income (HK$), Year and Type of Housing  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 Year
# 4                                      Type of Housing
# 5                                       Household Size
# ..                                                 ...
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
#
#                                   Unnamed: 1  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5    Monthly Domestic Household Income (HK$)
# ..                                       ...
# 106                          40,000 - 59,999
# 107                          60,000 - 79,999
# 108                          80,000 - 99,999
# 109                         100,000 and over
# 110                                    Total
#
#                                       Unnamed: 2  \
# 1    Economically Active Domestic Households (1)
# 2                                         Number
# 3                                           2021
# 4                          Public rental housing
# 5                                            NaN
# ..                                           ...
# 106                                        93597
# 107                                        26530
# 108                                         7048
# 109                                         2096
# 110                                       605602
#
#                             Unnamed: 3                 Unnamed: 4  \
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4    Subsidised home ownership housing  Private permanent housing
# 5                                  NaN                        NaN
# ..                                 ...                        ...
# 106                              76937                     214687
# 107                              34273                     143793
# 108                              15106                      89452
# 109                              10293                     214204
# 110                             330073                    1162089
#
#                Unnamed: 5         Unnamed: 6 Unnamed: 7
# 1                     NaN                NaN        NaN
# 2                     NaN                NaN        NaN
# 3                     NaN                NaN        NaN
# 4    Non-domestic housing  Temporary housing      Total
# 5                     NaN                NaN        NaN
# ..                    ...                ...        ...
# 106                  1753               2917     389891
# 107                  1081               1020     206697
# 108                   809                204     112619
# 109                  1629                335     228557
# 110                 10417              18139    2126320
#
# [110 rows x 8 columns]

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df11c.iloc[3,2:]):
    for inner_idx, householdSize in enumerate(df11c.iloc[5:,0].dropna()):
        for third_idx, householdIncome in enumerate(df11c.iloc[5:20,1]):
            new_row = [2021, housingType, householdSize, householdIncome, df11c.iloc[5+inner_idx * 15 + third_idx, idx+2], "Monthly household income expressed in HK$"]
            result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.iloc[629,3] = "Total"

# %%
result_df.columns = ["Year", "HousingType", "HouseholdSize", "MonthlyHouseholdIncomeRange", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#      Year            HousingType HouseholdSize MonthlyHouseholdIncomeRange  \
# 0    2021  Public rental housing             1             Less than 2,000
# 1    2021  Public rental housing             1               2,000 - 3,999
# 2    2021  Public rental housing             1               4,000 - 5,999
# 3    2021  Public rental housing             1               6,000 - 7,999
# 4    2021  Public rental housing             1               8,000 - 9,999
# ..    ...                    ...           ...                         ...
# 625  2021                  Total         Total             40,000 - 59,999
# 626  2021                  Total         Total             60,000 - 79,999
# 627  2021                  Total         Total             80,000 - 99,999
# 628  2021                  Total         Total            100,000 and over
# 629  2021                  Total         Total                       Total
#
#     NumberOfHouseholds                                Description
# 0                  601  Monthly household income expressed in HK$
# 1                 1977  Monthly household income expressed in HK$
# 2                 4683  Monthly household income expressed in HK$
# 3                 9066  Monthly household income expressed in HK$
# 4                 7309  Monthly household income expressed in HK$
# ..                 ...                                        ...
# 625             389891  Monthly household income expressed in HK$
# 626             206697  Monthly household income expressed in HK$
# 627             112619  Monthly household income expressed in HK$
# 628             228557  Monthly household income expressed in HK$
# 629            2126320  Monthly household income expressed in HK$
#
# [630 rows x 6 columns]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.EconomicallyActiveHouseholdByHousingTypeAndHouseholdSizeAndMonthlyHouseholdIncomeRange (Year, HousingType, HouseholdSize, MonthlyHouseholdIncomeRange, NumberOfHouseholds, Description) values(?,?,?,?,?,?)", row.Year, row.HousingType, row.HouseholdSize, row.MonthlyHouseholdIncomeRange, toEmptyOrFloat(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df11d = xl.parse("E111de")

# %%
df11d = df11d.iloc[1:13,:-2]

# %%
df11d
# Out:
#    Table E111d : Median Monthly Household Income of Economically Active Households by Household Size, Year and Type of Housing  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4                                     Type of Housing
# 5                                      Household Size
# 6                                                   1
# 7                                                   2
# 8                                                   3
# 9                                                   4
# 10                                                  5
# 11                                         6 and over
# 12                                            Overall
#
#                                            Unnamed: 1  \
# 1   Median Monthly Household Income of Economicall...
# 2                                                 HK$
# 3                                                2021
# 4                               Public rental housing
# 5                                                 NaN
# 6                                               11870
# 7                                               18630
# 8                                               26300
# 9                                               32960
# 10                                              36400
# 11                                              41040
# 12                                              24130
#
#                            Unnamed: 2                 Unnamed: 3  \
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4   Subsidised home ownership housing  Private permanent housing
# 5                                 NaN                        NaN
# 6                               18200                      25000
# 7                               25320                      40170
# 8                               34870                      43170
# 9                               44990                      59540
# 10                              51270                      79990
# 11                              55210                      88910
# 12                              34260                      46110
#
#               Unnamed: 4         Unnamed: 5 Unnamed: 6
# 1                    NaN                NaN        NaN
# 2                    NaN                NaN        NaN
# 3                    NaN                NaN        NaN
# 4   Non-domestic housing  Temporary housing    Overall
# 5                    NaN                NaN        NaN
# 6                  25240              11880      19000
# 7                  44920              18170      28000
# 8                  44570              24500      34190
# 9                  42230              32520      45240
# 10                 56210              31490      57840
# 11                 79400              45610      61040
# 12                 40040              23210      35040

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df11d.iloc[3,1:]):
    for inner_idx, householdSize in enumerate(df11d.iloc[5:,0]):
        new_row = [2021, housingType, householdSize, df11d.iloc[inner_idx+5, idx+1], "Monthly household income expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "HouseholdSize", "MedianMonthlyHouseholdIncome", "Description"]

# %%
result_df
# Out:
#     Year                        HousingType HouseholdSize  \
# 0   2021              Public rental housing             1
# 1   2021              Public rental housing             2
# 2   2021              Public rental housing             3
# 3   2021              Public rental housing             4
# 4   2021              Public rental housing             5
# 5   2021              Public rental housing    6 and over
# 6   2021              Public rental housing       Overall
# 7   2021  Subsidised home ownership housing             1
# 8   2021  Subsidised home ownership housing             2
# 9   2021  Subsidised home ownership housing             3
# 10  2021  Subsidised home ownership housing             4
# 11  2021  Subsidised home ownership housing             5
# 12  2021  Subsidised home ownership housing    6 and over
# 13  2021  Subsidised home ownership housing       Overall
# 14  2021          Private permanent housing             1
# 15  2021          Private permanent housing             2
# 16  2021          Private permanent housing             3
# 17  2021          Private permanent housing             4
# 18  2021          Private permanent housing             5
# 19  2021          Private permanent housing    6 and over
# 20  2021          Private permanent housing       Overall
# 21  2021               Non-domestic housing             1
# 22  2021               Non-domestic housing             2
# 23  2021               Non-domestic housing             3
# 24  2021               Non-domestic housing             4
# 25  2021               Non-domestic housing             5
# 26  2021               Non-domestic housing    6 and over
# 27  2021               Non-domestic housing       Overall
# 28  2021                  Temporary housing             1
# 29  2021                  Temporary housing             2
# 30  2021                  Temporary housing             3
# 31  2021                  Temporary housing             4
# 32  2021                  Temporary housing             5
# 33  2021                  Temporary housing    6 and over
# 34  2021                  Temporary housing       Overall
# 35  2021                            Overall             1
# 36  2021                            Overall             2
# 37  2021                            Overall             3
# 38  2021                            Overall             4
# 39  2021                            Overall             5
# 40  2021                            Overall    6 and over
# 41  2021                            Overall       Overall
#
#     MedianMonthlyHouseholdIncome                                Description
# 0                          11870  Monthly household income expressed in HK$
# 1                          18630  Monthly household income expressed in HK$
# 2                          26300  Monthly household income expressed in HK$
# 3                          32960  Monthly household income expressed in HK$
# 4                          36400  Monthly household income expressed in HK$
# 5                          41040  Monthly household income expressed in HK$
# 6                          24130  Monthly household income expressed in HK$
# 7                          18200  Monthly household income expressed in HK$
# 8                          25320  Monthly household income expressed in HK$
# 9                          34870  Monthly household income expressed in HK$
# 10                         44990  Monthly household income expressed in HK$
# 11                         51270  Monthly household income expressed in HK$
# 12                         55210  Monthly household income expressed in HK$
# 13                         34260  Monthly household income expressed in HK$
# 14                         25000  Monthly household income expressed in HK$
# 15                         40170  Monthly household income expressed in HK$
# 16                         43170  Monthly household income expressed in HK$
# 17                         59540  Monthly household income expressed in HK$
# 18                         79990  Monthly household income expressed in HK$
# 19                         88910  Monthly household income expressed in HK$
# 20                         46110  Monthly household income expressed in HK$
# 21                         25240  Monthly household income expressed in HK$
# 22                         44920  Monthly household income expressed in HK$
# 23                         44570  Monthly household income expressed in HK$
# 24                         42230  Monthly household income expressed in HK$
# 25                         56210  Monthly household income expressed in HK$
# 26                         79400  Monthly household income expressed in HK$
# 27                         40040  Monthly household income expressed in HK$
# 28                         11880  Monthly household income expressed in HK$
# 29                         18170  Monthly household income expressed in HK$
# 30                         24500  Monthly household income expressed in HK$
# 31                         32520  Monthly household income expressed in HK$
# 32                         31490  Monthly household income expressed in HK$
# 33                         45610  Monthly household income expressed in HK$
# 34                         23210  Monthly household income expressed in HK$
# 35                         19000  Monthly household income expressed in HK$
# 36                         28000  Monthly household income expressed in HK$
# 37                         34190  Monthly household income expressed in HK$
# 38                         45240  Monthly household income expressed in HK$
# 39                         57840  Monthly household income expressed in HK$
# 40                         61040  Monthly household income expressed in HK$
# 41                         35040  Monthly household income expressed in HK$

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.EconomicallyActiveHouseholdIncomeByHousingTypeAndHouseholdSize (Year, HousingType, HouseholdSize, MedianMonthlyHouseholdIncome, Description) values(?,?,?,?,?)", row.Year, row.HousingType, row.HouseholdSize, row.MedianMonthlyHouseholdIncome, row.Description) 
cnxn.commit()
cursor.close()

# %%
df12 = xl.parse("E112e")

# %%
df12 = df12.iloc[1:13,:-2]

# %%
df12
# Out:
#    Table E112 : Occupied Quarters by Type of Quarters, Year and Number of Domestic Households in Each Unit of Quarters  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4   Number of Domestic Households in Each Unit of ...
# 5                                    Type of Quarters
# 6                         Public rental housing units
# 7                               Subsidised sale flats
# 8                           Private residential flats
# 9         Other quarters in private permanent housing
# 10                              Non-domestic quarters
# 11                                 Temporary quarters
# 12                                              Total
#
#                     Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 1            Occupied Quarters         NaN        NaN        NaN        NaN
# 2   Number of Unit of Quarters         NaN        NaN        NaN        NaN
# 3                         2021         NaN        NaN        NaN        NaN
# 4                        0 (1)         1.0          2         3+      Total
# 5                          NaN         NaN        NaN        NaN        NaN
# 6                         1297    807264.0         20         --     808581
# 7                          680    413788.0         --         --     414468
# 8                         4506   1204302.0        753        309    1209870
# 9                         1033    208259.0        271         45     209608
# 10                        9073     12921.0         19         41      22054
# 11                          46     24175.0         10         --      24231
# 12                       16635   2670709.0       1073        395    2688812

# %%
result_df = pd.DataFrame()

# %%
for idx, numberOfHouseholds in enumerate(df12.iloc[3,1:]):
    for inner_idx, housingType in enumerate(df12.iloc[5:,0]):
        new_row = [2021, re.sub(r'\([^)]*\)', '', str(numberOfHouseholds)), housingType, df12.iloc[5+inner_idx, idx+1], "0 number of households refers to quarters occupied by non-domestic householders"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "NumberOfHouseholds", "HousingType", "NumberOfOccupiedQuarters", "Description"]

# %%
result_df
# Out:
#     Year NumberOfHouseholds                                  HousingType  \
# 0   2021                 0                   Public rental housing units
# 1   2021                 0                         Subsidised sale flats
# 2   2021                 0                     Private residential flats
# 3   2021                 0   Other quarters in private permanent housing
# 4   2021                 0                         Non-domestic quarters
# 5   2021                 0                            Temporary quarters
# 6   2021                 0                                         Total
# 7   2021                1.0                  Public rental housing units
# 8   2021                1.0                        Subsidised sale flats
# 9   2021                1.0                    Private residential flats
# 10  2021                1.0  Other quarters in private permanent housing
# 11  2021                1.0                        Non-domestic quarters
# 12  2021                1.0                           Temporary quarters
# 13  2021                1.0                                        Total
# 14  2021                  2                  Public rental housing units
# 15  2021                  2                        Subsidised sale flats
# 16  2021                  2                    Private residential flats
# 17  2021                  2  Other quarters in private permanent housing
# 18  2021                  2                        Non-domestic quarters
# 19  2021                  2                           Temporary quarters
# 20  2021                  2                                        Total
# 21  2021                 3+                  Public rental housing units
# 22  2021                 3+                        Subsidised sale flats
# 23  2021                 3+                    Private residential flats
# 24  2021                 3+  Other quarters in private permanent housing
# 25  2021                 3+                        Non-domestic quarters
# 26  2021                 3+                           Temporary quarters
# 27  2021                 3+                                        Total
# 28  2021              Total                  Public rental housing units
# 29  2021              Total                        Subsidised sale flats
# 30  2021              Total                    Private residential flats
# 31  2021              Total  Other quarters in private permanent housing
# 32  2021              Total                        Non-domestic quarters
# 33  2021              Total                           Temporary quarters
# 34  2021              Total                                        Total
#
#    NumberOfOccupiedQuarters                                        Description
# 0                    1297.0  0 number of households refers to quarters occu...
# 1                     680.0  0 number of households refers to quarters occu...
# 2                    4506.0  0 number of households refers to quarters occu...
# 3                    1033.0  0 number of households refers to quarters occu...
# 4                    9073.0  0 number of households refers to quarters occu...
# 5                      46.0  0 number of households refers to quarters occu...
# 6                   16635.0  0 number of households refers to quarters occu...
# 7                  807264.0  0 number of households refers to quarters occu...
# 8                  413788.0  0 number of households refers to quarters occu...
# 9                 1204302.0  0 number of households refers to quarters occu...
# 10                 208259.0  0 number of households refers to quarters occu...
# 11                  12921.0  0 number of households refers to quarters occu...
# 12                  24175.0  0 number of households refers to quarters occu...
# 13                2670709.0  0 number of households refers to quarters occu...
# 14                     20.0  0 number of households refers to quarters occu...
# 15                       --  0 number of households refers to quarters occu...
# 16                      753  0 number of households refers to quarters occu...
# 17                      271  0 number of households refers to quarters occu...
# 18                       19  0 number of households refers to quarters occu...
# 19                       10  0 number of households refers to quarters occu...
# 20                     1073  0 number of households refers to quarters occu...
# 21                       --  0 number of households refers to quarters occu...
# 22                       --  0 number of households refers to quarters occu...
# 23                      309  0 number of households refers to quarters occu...
# 24                       45  0 number of households refers to quarters occu...
# 25                       41  0 number of households refers to quarters occu...
# 26                       --  0 number of households refers to quarters occu...
# 27                      395  0 number of households refers to quarters occu...
# 28                   808581  0 number of households refers to quarters occu...
# 29                   414468  0 number of households refers to quarters occu...
# 30                  1209870  0 number of households refers to quarters occu...
# 31                   209608  0 number of households refers to quarters occu...
# 32                    22054  0 number of households refers to quarters occu...
# 33                    24231  0 number of households refers to quarters occu...
# 34                  2688812  0 number of households refers to quarters occu...

# %%
def toEmptyOrInt(value):
    if (str(value) == "--"):
        pass
    else:
        return int(value)

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.OccupiedQuarterByNumberOfHouseholdsAndHousingType (Year, NumberOfHouseholds, HousingType, NumberOfOccupiedQuarters, Description) values(?,?,?,?,?)", row.Year, row.NumberOfHouseholds, row.HousingType, toEmptyOrInt(row.NumberOfOccupiedQuarters), row.Description) 
cnxn.commit()
cursor.close()

# %%
df13 = xl.parse("E113e")

# %%
df13 = df13.iloc[1:13,:-2]

# %%
result_df = pd.DataFrame()
# Out:
#    Table E113 : Occupied Quarters by Type of Quarters, Year and Number of Occupants in Each Unit of Quarters  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4        Number of Occupants in Each Unit of Quarters
# 5                                    Type of Quarters
# 6                         Public rental housing units
# 7                               Subsidised sale flats
# 8                           Private residential flats
# 9         Other quarters in private permanent housing
# 10                              Non-domestic quarters
# 11                                 Temporary quarters
# 12                                              Total
#
#                     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 1            Occupied Quarters         NaN         NaN         NaN
# 2   Number of Unit of Quarters         NaN         NaN         NaN
# 3                         2021         NaN         NaN         NaN
# 4                            1         2.0         3.0         4.0
# 5                          NaN         NaN         NaN         NaN
# 6                       175159    220921.0    200631.0    139951.0
# 7                        60178    128546.0    115456.0     72509.0
# 8                       259158    352412.0    271459.0    199704.0
# 9                        35647     56156.0     46958.0     39693.0
# 10                        9391      4856.0      2713.0      2149.0
# 11                        7211      6768.0      4473.0      3189.0
# 12                      546744    769659.0    641690.0    457195.0
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7
# 1          NaN        NaN        NaN
# 2          NaN        NaN        NaN
# 3          NaN        NaN        NaN
# 4          5.0         6+      Total
# 5          NaN        NaN        NaN
# 6      50993.0      20926     808581
# 7      26812.0      10967     414468
# 8      93528.0      33609    1209870
# 9      19607.0      11547     209608
# 10       627.0       2318      22054
# 11       914.0       1676      24231
# 12    192481.0      81043    2688812

# %%
df13.iloc[3,2] = str(2)
df13.iloc[3,3] = str(3)
df13.iloc[3,4] = str(4)
df13.iloc[3,5] = str(5)
# Out:
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_23760\456229583.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df13.iloc[3,2] = str(2)
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_23760\456229583.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df13.iloc[3,3] = str(3)
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_23760\456229583.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df13.iloc[3,4] = str(4)
# C:\Users\lucius_wong\AppData\Local\Temp\ipykernel_23760\456229583.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df13.iloc[3,5] = str(5)

# %%
df13
# Out:
#    Table E113 : Occupied Quarters by Type of Quarters, Year and Number of Occupants in Each Unit of Quarters  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4        Number of Occupants in Each Unit of Quarters
# 5                                    Type of Quarters
# 6                         Public rental housing units
# 7                               Subsidised sale flats
# 8                           Private residential flats
# 9         Other quarters in private permanent housing
# 10                              Non-domestic quarters
# 11                                 Temporary quarters
# 12                                              Total
#
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1            Occupied Quarters        NaN        NaN        NaN        NaN
# 2   Number of Unit of Quarters        NaN        NaN        NaN        NaN
# 3                         2021        NaN        NaN        NaN        NaN
# 4                            1          2          3          4          5
# 5                          NaN        NaN        NaN        NaN        NaN
# 6                       175159   220921.0   200631.0   139951.0    50993.0
# 7                        60178   128546.0   115456.0    72509.0    26812.0
# 8                       259158   352412.0   271459.0   199704.0    93528.0
# 9                        35647    56156.0    46958.0    39693.0    19607.0
# 10                        9391     4856.0     2713.0     2149.0      627.0
# 11                        7211     6768.0     4473.0     3189.0      914.0
# 12                      546744   769659.0   641690.0   457195.0   192481.0
#
#    Unnamed: 6 Unnamed: 7
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4          6+      Total
# 5         NaN        NaN
# 6       20926     808581
# 7       10967     414468
# 8       33609    1209870
# 9       11547     209608
# 10       2318      22054
# 11       1676      24231
# 12      81043    2688812

# %%
result_df = pd.DataFrame()

# %%
for idx, numberOfOccupants in enumerate(df13.iloc[3,1:]):
    for inner_idx, housingType in enumerate(df13.iloc[5:,0]):
        new_row = [2021, housingType, numberOfOccupants, df13.iloc[5+inner_idx,idx+1]]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "NumberOfOccupants", "NumberOfOccupiedQuarters"]

# %%
result_df
# Out:
#     Year                                  HousingType NumberOfOccupants  \
# 0   2021                  Public rental housing units                 1
# 1   2021                        Subsidised sale flats                 1
# 2   2021                    Private residential flats                 1
# 3   2021  Other quarters in private permanent housing                 1
# 4   2021                        Non-domestic quarters                 1
# 5   2021                           Temporary quarters                 1
# 6   2021                                        Total                 1
# 7   2021                  Public rental housing units                 2
# 8   2021                        Subsidised sale flats                 2
# 9   2021                    Private residential flats                 2
# 10  2021  Other quarters in private permanent housing                 2
# 11  2021                        Non-domestic quarters                 2
# 12  2021                           Temporary quarters                 2
# 13  2021                                        Total                 2
# 14  2021                  Public rental housing units                 3
# 15  2021                        Subsidised sale flats                 3
# 16  2021                    Private residential flats                 3
# 17  2021  Other quarters in private permanent housing                 3
# 18  2021                        Non-domestic quarters                 3
# 19  2021                           Temporary quarters                 3
# 20  2021                                        Total                 3
# 21  2021                  Public rental housing units                 4
# 22  2021                        Subsidised sale flats                 4
# 23  2021                    Private residential flats                 4
# 24  2021  Other quarters in private permanent housing                 4
# 25  2021                        Non-domestic quarters                 4
# 26  2021                           Temporary quarters                 4
# 27  2021                                        Total                 4
# 28  2021                  Public rental housing units                 5
# 29  2021                        Subsidised sale flats                 5
# 30  2021                    Private residential flats                 5
# 31  2021  Other quarters in private permanent housing                 5
# 32  2021                        Non-domestic quarters                 5
# 33  2021                           Temporary quarters                 5
# 34  2021                                        Total                 5
# 35  2021                  Public rental housing units                6+
# 36  2021                        Subsidised sale flats                6+
# 37  2021                    Private residential flats                6+
# 38  2021  Other quarters in private permanent housing                6+
# 39  2021                        Non-domestic quarters                6+
# 40  2021                           Temporary quarters                6+
# 41  2021                                        Total                6+
# 42  2021                  Public rental housing units             Total
# 43  2021                        Subsidised sale flats             Total
# 44  2021                    Private residential flats             Total
# 45  2021  Other quarters in private permanent housing             Total
# 46  2021                        Non-domestic quarters             Total
# 47  2021                           Temporary quarters             Total
# 48  2021                                        Total             Total
#
#     NumberOfOccupiedQuarters
# 0                   175159.0
# 1                    60178.0
# 2                   259158.0
# 3                    35647.0
# 4                     9391.0
# 5                     7211.0
# 6                   546744.0
# 7                   220921.0
# 8                   128546.0
# 9                   352412.0
# 10                   56156.0
# 11                    4856.0
# 12                    6768.0
# 13                  769659.0
# 14                  200631.0
# 15                  115456.0
# 16                  271459.0
# 17                   46958.0
# 18                    2713.0
# 19                    4473.0
# 20                  641690.0
# 21                  139951.0
# 22                   72509.0
# 23                  199704.0
# 24                   39693.0
# 25                    2149.0
# 26                    3189.0
# 27                  457195.0
# 28                   50993.0
# 29                   26812.0
# 30                   93528.0
# 31                   19607.0
# 32                     627.0
# 33                     914.0
# 34                  192481.0
# 35                   20926.0
# 36                   10967.0
# 37                   33609.0
# 38                   11547.0
# 39                    2318.0
# 40                    1676.0
# 41                   81043.0
# 42                  808581.0
# 43                  414468.0
# 44                 1209870.0
# 45                  209608.0
# 46                   22054.0
# 47                   24231.0
# 48                 2688812.0

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.OccupiedQuarterByHousingTypeAndNumberOfOccupants (Year, HousingType, NumberOfOccupants, NumberOfOccupiedQuarters) values(?,?,?,?)", row.Year, row.HousingType, row.NumberOfOccupants, toEmptyOrInt(row.NumberOfOccupiedQuarters)) 
cnxn.commit()
cursor.close()

# %%
df14 = xl.parse("E114e")

# %%
df14 = df14.iloc[1:63,:-2]

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df14.iloc[3,2:]):
    for inner_idx, sex in enumerate(df14.iloc[5:,0].dropna()):
        for third_idx, ageRange in enumerate(df14.iloc[5:24,1]):
            new_row = [2021, housingType, sex, ageRange, df14.iloc[5+inner_idx*19+third_idx,idx+2]]
            result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.iloc[341,3] = "Total"

# %%
result_df.columns = ["Year", "HousingType", "Sex", "AgeRange", "NumberOfPersons"]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.PopulationByHousingTypeAndSexAndAgeRange (Year, HousingType, Sex, AgeRange, NumberOfPersons) values(?,?,?,?,?)", row.Year, row.HousingType, row.Sex, row.AgeRange, toEmptyOrInt(row.NumberOfPersons)) 
cnxn.commit()
cursor.close()

# %%
df15 = xl.parse("E115e")

# %%
df15 = df15.iloc[1:12,:-2]

# %%
df15
# Out:
#    Table E115 : Population in Domestic Households by Type of Housing, Year and Educational Attainment (Highest Level Attended)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4     Educational Attainment (Highest Level Attended)
# 5                                     Type of Housing
# 6                               Public rental housing
# 7                   Subsidised home ownership housing
# 8                           Private permanent housing
# 9                                Non-domestic housing
# 10                                  Temporary housing
# 11                                              Total
#
#                            Unnamed: 1 Unnamed: 2       Unnamed: 3  \
# 1   Population in Domestic Households        NaN              NaN
# 2                   Number of Persons        NaN              NaN
# 3                                2021        NaN              NaN
# 4           No schooling/ Pre-primary    Primary  Lower secondary
# 5                                 NaN        NaN              NaN
# 6                              186720     497499           509652
# 7                               92076     227234           213158
# 8                              285969     494258           514121
# 9                                1993       3059             2792
# 10                               5604      13490            14829
# 11                             572362    1235540          1254552
#
#          Unnamed: 4                            Unnamed: 5  \
# 1               NaN                                   NaN
# 2               NaN                                   NaN
# 3               NaN                                   NaN
# 4   Upper secondary  Post-secondary: Diploma/ Certificate
# 5               NaN                                   NaN
# 6            571022                                 91891
# 7            324257                                 61527
# 8           1034776                                220212
# 9              6791                                  1490
# 10            18326                                  1875
# 11          1955172                                376995
#
#                            Unnamed: 6                     Unnamed: 7  \
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4   Post-secondary: Sub-degree course  Post-secondary: Degree course
# 5                                 NaN                            NaN
# 6                               97861                         209425
# 7                               53965                         183810
# 8                              179093                        1137723
# 9                                1035                          10645
# 10                               2370                           5784
# 11                             334324                        1547387
#
#    Unnamed: 8
# 1         NaN
# 2         NaN
# 3         NaN
# 4       Total
# 5         NaN
# 6     2164070
# 7     1156027
# 8     3866152
# 9       27805
# 10      62278
# 11    7276332

# %%
result_df = pd.DataFrame()

# %%
for idx, housingType in enumerate(df15.iloc[5:,0]):
    for inner_idx, education in enumerate(df15.iloc[3,1:]):
        new_row = [2021, housingType, education, df15.iloc[5+idx,inner_idx+1]]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HousingType", "Education", "NumberOfPersons"]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.PopulationByHousingTypeAndEducation (Year, HousingType, Education, NumberOfPersons) values(?,?,?,?)", row.Year, row.HousingType, row.Education, toEmptyOrInt(row.NumberOfPersons)) 
cnxn.commit()
cursor.close()

# %%
df16 = xl.parse("E116e")

# %%
df16 = df16.iloc[3:20,:-2]

# %%
df16
# Out:
#    Table E116 : Domestic Households by Monthly Domestic Household Mortgage Payment and Loan Repayment (HK$), Year and Monthly Domestic Household Income (HK$)  \
# 3                                                Year
# 4             Monthly Domestic Household Income (HK$)
# 5   Monthly Domestic Household Mortgage Payment an...
# 6                       By non-household members only
# 7                                           1 - 1,999
# 8                                       2,000 - 3,999
# 9                                       4,000 - 5,999
# 10                                      6,000 - 7,999
# 11                                      8,000 - 9,999
# 12                                    10,000 - 14,999
# 13                                    15,000 - 19,999
# 14                                    20,000 - 24,999
# 15                                    25,000 - 29,999
# 16                                    30,000 - 39,999
# 17                                    40,000 and over
# 18  Not required to pay mortgage payment and loan ...
# 19                                              Total
#
#          Unnamed: 1     Unnamed: 2     Unnamed: 3     Unnamed: 4  \
# 3              2021            NaN            NaN            NaN
# 4   Less than 2,000  2,000 - 3,999  4,000 - 5,999  6,000 - 7,999
# 5               NaN            NaN            NaN            NaN
# 6             10841           3690           4681           2635
# 7               242            382            416             82
# 8               243            189            255            390
# 9               219             30             47            335
# 10              246              6             33             91
# 11              264             19             39             84
# 12              387             23            132            158
# 13              308             --             29             49
# 14              115             --             41             26
# 15               49             --             12              6
# 16               23             --              6             --
# 17               10             --              5             23
# 18           106634          62901         102103         116215
# 19           119581          67240         107799         120094
#
#        Unnamed: 5       Unnamed: 6       Unnamed: 7       Unnamed: 8  \
# 3             NaN              NaN              NaN              NaN
# 4   8,000 - 9,999  10,000 - 14,999  15,000 - 19,999  20,000 - 24,999
# 5             NaN              NaN              NaN              NaN
# 6            2886             4383             3619             2636
# 7             407             1051              979              799
# 8             353             1855             2245             2248
# 9             711             2024             2630             3322
# 10            301             2106             3017             3345
# 11            208             1668             2139             2800
# 12            343             2415             3068             5585
# 13             92              548             1246             2103
# 14            100              196              325              515
# 15             30               52               86              132
# 16             45               83               52              133
# 17              9               60               82              184
# 18         101840           243033           210747           200101
# 19         107325           259474           230235           223903
#
#          Unnamed: 9      Unnamed: 10      Unnamed: 11      Unnamed: 12  \
# 3               NaN              NaN              NaN              NaN
# 4   25,000 - 29,999  30,000 - 39,999  40,000 - 59,999  60,000 - 79,999
# 5               NaN              NaN              NaN              NaN
# 6              1032             2473             3897             2322
# 7               677             1149             1891              758
# 8              1933             3944             4270             1908
# 9              3175             6457             8198             3884
# 10             2863             6531             9954             4762
# 11             3027             6409             9594             5413
# 12             5159            14463            25527            18047
# 13             2170             5969            15109            12456
# 14              679             2098             5962             6515
# 15              199              838             1870             2295
# 16              133              653             1434             1429
# 17              142              374             1481             1124
# 18           150727           256084           310141           150408
# 19           171916           307442           399328           211321
#
#         Unnamed: 13       Unnamed: 14 Unnamed: 15
# 3               NaN               NaN         NaN
# 4   80,000 - 99,999  100,000 and over       Total
# 5               NaN               NaN         NaN
# 6              1226              2392       48713
# 7               379               519        9731
# 8               718               800       21351
# 9              1649              1648       34329
# 10             2342              2839       38436
# 11             2747              3539       37950
# 12             9850             14550       99707
# 13             8617             18622       67318
# 14             5616             14361       36549
# 15             2495              8358       16422
# 16             1554              8992       14537
# 17             1119             10504       15117
# 18            76566            146501     2234001
# 19           114878            233625     2674161

# %%
result_df = pd.DataFrame()

# %%
for idx, householdIncome in enumerate(df16.iloc[1,1:]):
    for inner_idx, mortgagePayment in enumerate(df16.iloc[3:,0]):
        new_row = [2021, householdIncome, re.sub(r'\([^)]*\)', '', mortgagePayment), df16.iloc[3+inner_idx,idx+1], "Income and mortgage payments expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "MonthlyHouseholdIncome", "MonthlyMortgagePayment", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#      Year MonthlyHouseholdIncome  \
# 0    2021        Less than 2,000
# 1    2021        Less than 2,000
# 2    2021        Less than 2,000
# 3    2021        Less than 2,000
# 4    2021        Less than 2,000
# ..    ...                    ...
# 205  2021                  Total
# 206  2021                  Total
# 207  2021                  Total
# 208  2021                  Total
# 209  2021                  Total
#
#                                 MonthlyMortgagePayment NumberOfHouseholds  \
# 0                        By non-household members only              10841
# 1                                            1 - 1,999                242
# 2                                        2,000 - 3,999                243
# 3                                        4,000 - 5,999                219
# 4                                        6,000 - 7,999                246
# ..                                                 ...                ...
# 205                                    25,000 - 29,999              16422
# 206                                    30,000 - 39,999              14537
# 207                                    40,000 and over              15117
# 208  Not required to pay mortgage payment and loan ...            2234001
# 209                                              Total            2674161
#
#                                        Description
# 0    Income and mortgage payments expressed in HK$
# 1    Income and mortgage payments expressed in HK$
# 2    Income and mortgage payments expressed in HK$
# 3    Income and mortgage payments expressed in HK$
# 4    Income and mortgage payments expressed in HK$
# ..                                             ...
# 205  Income and mortgage payments expressed in HK$
# 206  Income and mortgage payments expressed in HK$
# 207  Income and mortgage payments expressed in HK$
# 208  Income and mortgage payments expressed in HK$
# 209  Income and mortgage payments expressed in HK$
#
# [210 rows x 5 columns]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdByMonthlyHouseholdIncomeAndMonthlyMortgagePayment (Year, MonthlyHouseholdIncome, MonthlyMortgagePayment, NumberOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.MonthlyHouseholdIncome, row.MonthlyMortgagePayment, toEmptyOrInt(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[533], line 4
#       2 # Insert Dataframe into SQL Server:
#       3 for index, row in result_df.iterrows():
# ----> 4     cursor.execute("INSERT INTO Population.HouseholdByMonthlyHouseholdIncomeAndMonthlyMortgagePayment (Year, MonthlyHouseholdIncome, MonthlyMortgagePayment, NumberOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.MonthlyHouseholdIncome, row.MonthlyMortgagePayment, toEmptyOrInt(row.NumberOfHouseholds), row.Description)
#       5 cnxn.commit()
#       6 cursor.close()
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]String or binary data would be truncated in table 'db-at-dev-gas-sale-01.Population.HouseholdByMonthlyHouseholdIncomeAndMonthlyMortgagePayment', column 'MonthlyMortgagePayment'. Truncated value: 'Not required to pay mortgage payment and loan repa'. (2628) (SQLExecDirectW); [42000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")

# %%
df17 = xl.parse("E117e")

# %%
df17 = df17.iloc[1:22,:-2]

# %%
df17
# Out:
#    Table E117 : Domestic Households by Monthly Domestic Household Rent (HK$), Year and Monthly Domestic Household Income (HK$)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4             Monthly Domestic Household Income (HK$)
# 5               Monthly Domestic Household Rent (HK$)
# 6                                               0 (1)
# 7                                             1 - 999
# 8                                       1,000 - 1,499
# 9                                       1,500 - 1,999
# 10                                      2,000 - 3,999
# 11                                      4,000 - 5,999
# 12                                      6,000 - 7,999
# 13                                      8,000 - 9,999
# 14                                    10,000 - 14,999
# 15                                    15,000 - 19,999
# 16                                    20,000 - 24,999
# 17                                    25,000 - 29,999
# 18                                    30,000 - 39,999
# 19                                    40,000 and over
# 20                       Not required to pay rent (2)
# 21                                              Total
#
#              Unnamed: 1     Unnamed: 2     Unnamed: 3     Unnamed: 4  \
# 1   Domestic Households            NaN            NaN            NaN
# 2                Number            NaN            NaN            NaN
# 3                  2021            NaN            NaN            NaN
# 4       Less than 2,000  2,000 - 3,999  4,000 - 5,999  6,000 - 7,999
# 5                   NaN            NaN            NaN            NaN
# 6                   239             73            204            164
# 7                  1526           2558           6899           5167
# 8                  6458           8488          17033          22751
# 9                  6697           8863          11362          22251
# 10                13696          10067          16588          21394
# 11                 4885           1080           1847           4661
# 12                 2394            239            481           1793
# 13                 2262            449            559           1183
# 14                 3987            665           1235           3238
# 15                 2310            279            709           1344
# 16                  838            180            360            385
# 17                  510             35            194             84
# 18                  390             28            226            126
# 19                  657            109            394            206
# 20                72732          34127          49708          35347
# 21               119581          67240         107799         120094
#
#        Unnamed: 5       Unnamed: 6       Unnamed: 7       Unnamed: 8  \
# 1             NaN              NaN              NaN              NaN
# 2             NaN              NaN              NaN              NaN
# 3             NaN              NaN              NaN              NaN
# 4   8,000 - 9,999  10,000 - 14,999  15,000 - 19,999  20,000 - 24,999
# 5             NaN              NaN              NaN              NaN
# 6              96              248              309              220
# 7            2978             5020             2428             1109
# 8           13328            28880            17080            11546
# 9           12710            30118            21996            18686
# 10          20488            60551            55977            54593
# 11           4174            19260            16330            12401
# 12           1670             8787             8655             7067
# 13           1218             4464             4585             4564
# 14           1878             6432             8522            10784
# 15           1059             2234             2812             3289
# 16            346              925              968              975
# 17            211              377              357              318
# 18            156              496              338              312
# 19            269              461              445              512
# 20          46744            91221            89433            97527
# 21         107325           259474           230235           223903
#
#          Unnamed: 9      Unnamed: 10      Unnamed: 11      Unnamed: 12  \
# 1               NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN
# 4   25,000 - 29,999  30,000 - 39,999  40,000 - 59,999  60,000 - 79,999
# 5               NaN              NaN              NaN              NaN
# 6               228              400              735              450
# 7               623              890              537              385
# 8              7152             8302             5425             1612
# 9             13903            19736            17725             5033
# 10            41319            66751            67351            20368
# 11             9043            14804            15782             6188
# 12             4370             5115             4395             1537
# 13             3850             6212             5713             2220
# 14             8857            16244            25391            12322
# 15             2535             6812            12942            11893
# 16              863             2527             5067             5590
# 17              363              913             1986             2011
# 18              193              834             1591             1928
# 19              443              708             1468             1390
# 20            78174           157194           233220           138394
# 21           171916           307442           399328           211321
#
#         Unnamed: 13       Unnamed: 14 Unnamed: 15
# 1               NaN               NaN         NaN
# 2               NaN               NaN         NaN
# 3               NaN               NaN         NaN
# 4   80,000 - 99,999  100,000 and over       Total
# 5               NaN               NaN         NaN
# 6               434              1211        5011
# 7                77               298       30495
# 8               286               190      148531
# 9              1391               802      191273
# 10             6182              2973      458298
# 11             2214              1556      114225
# 12              755               976       48234
# 13             1038              1293       39610
# 14             5109              7026      111690
# 15             6961             12253       67432
# 16             4793             11103       34920
# 17             1907              7652       16918
# 18             1824             10414       18856
# 19             1649             15864       24575
# 20            80258            160014     1364093
# 21           114878            233625     2674161

# %%
result_df = pd.DataFrame()

# %%
for idx, monthlyIncome in enumerate(df17.iloc[3,1:]):
    for inner_idx, monthlyRent in enumerate(df17.iloc[5:,0]):
        new_row = [2021, monthlyIncome, re.sub(r'\([^)]*\)', '', monthlyRent), df17.iloc[5+inner_idx,idx+1], "Income and rent expressed in HK$"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "MonthlyHouseholdIncome", "MonthlyRent", "NumberOfHouseholds", "Description"]

# %%
result_df
# Out:
#      Year MonthlyHouseholdIncome                MonthlyRent  \
# 0    2021        Less than 2,000                         0
# 1    2021        Less than 2,000                    1 - 999
# 2    2021        Less than 2,000              1,000 - 1,499
# 3    2021        Less than 2,000              1,500 - 1,999
# 4    2021        Less than 2,000              2,000 - 3,999
# ..    ...                    ...                        ...
# 235  2021                  Total            25,000 - 29,999
# 236  2021                  Total            30,000 - 39,999
# 237  2021                  Total            40,000 and over
# 238  2021                  Total  Not required to pay rent
# 239  2021                  Total                      Total
#
#      NumberOfHouseholds                       Description
# 0                   239  Income and rent expressed in HK$
# 1                  1526  Income and rent expressed in HK$
# 2                  6458  Income and rent expressed in HK$
# 3                  6697  Income and rent expressed in HK$
# 4                 13696  Income and rent expressed in HK$
# ..                  ...                               ...
# 235               16918  Income and rent expressed in HK$
# 236               18856  Income and rent expressed in HK$
# 237               24575  Income and rent expressed in HK$
# 238             1364093  Income and rent expressed in HK$
# 239             2674161  Income and rent expressed in HK$
#
# [240 rows x 5 columns]

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdByMonthlyHouseholdIncomeAndMonthlyRent (Year, MonthlyHouseholdIncome, MonthlyRent, NumberOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.MonthlyHouseholdIncome, row.MonthlyRent, toEmptyOrInt(row.NumberOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df18a = xl.parse("E118ae")

# %%
df18a = df18a.iloc[1:14,:-2]

# %%
df18a
# Out:
#    Table E118a : Domestic Households by Floor Area of Accommodation (Square Metres) and Year  \
# 1                                                Year
# 2                                                 NaN
# 3                                                 NaN
# 4     Floor Area of Accommodation (Square Metres) (1)
# 5                                         Less than 7
# 6                                               7-<13
# 7                                              13-<20
# 8                                              20-<40
# 9                                              40-<70
# 10                                            70-<100
# 11                                           100-<160
# 12                                       160 and over
# 13                                              Total
#
#              Unnamed: 1  Unnamed: 2           Unnamed: 3  Unnamed: 4
# 1                  2016         NaN                 2021         NaN
# 2   Domestic Households         NaN  Domestic Households         NaN
# 3                Number  Percentage               Number  Percentage
# 4                   NaN         NaN                  NaN         NaN
# 5                 12554         0.5                12651         0.5
# 6                 80095         3.2                77410         2.9
# 7                110934         4.4               134547           5
# 8                990937        39.5              1028857        38.5
# 9               1071400        42.7              1168077        43.7
# 10               145211         5.8               152149         5.7
# 11                66824         2.7                69162         2.6
# 12                30479         1.2                29299         1.1
# 13              2508434         100              2672152         100

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df18a.iloc[0,1:].dropna()):
    for inner_idx, floorArea in enumerate(df18a.iloc[4:,0]):
        new_row = [year, floorArea, df18a.iloc[4+inner_idx,1+idx*2], df18a.iloc[4+inner_idx,2+idx*2], "Household accommodation area expressed in sqaure meters"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HouseholdAccommodationArea", "NumberOfHouseholds", "PercentageOfHouseholds", "Description"]

# %%
result_df
# Out:
#     Year HouseholdAccommodationArea  NumberOfHouseholds  \
# 0   2016                Less than 7               12554
# 1   2016                      7-<13               80095
# 2   2016                     13-<20              110934
# 3   2016                     20-<40              990937
# 4   2016                     40-<70             1071400
# 5   2016                    70-<100              145211
# 6   2016                   100-<160               66824
# 7   2016               160 and over               30479
# 8   2016                      Total             2508434
# 9   2021                Less than 7               12651
# 10  2021                      7-<13               77410
# 11  2021                     13-<20              134547
# 12  2021                     20-<40             1028857
# 13  2021                     40-<70             1168077
# 14  2021                    70-<100              152149
# 15  2021                   100-<160               69162
# 16  2021               160 and over               29299
# 17  2021                      Total             2672152
#
#     PercentageOfHouseholds                                        Description
# 0                      0.5  Household accommodation area expressed in sqau...
# 1                      3.2  Household accommodation area expressed in sqau...
# 2                      4.4  Household accommodation area expressed in sqau...
# 3                     39.5  Household accommodation area expressed in sqau...
# 4                     42.7  Household accommodation area expressed in sqau...
# 5                      5.8  Household accommodation area expressed in sqau...
# 6                      2.7  Household accommodation area expressed in sqau...
# 7                      1.2  Household accommodation area expressed in sqau...
# 8                    100.0  Household accommodation area expressed in sqau...
# 9                      0.5  Household accommodation area expressed in sqau...
# 10                     2.9  Household accommodation area expressed in sqau...
# 11                     5.0  Household accommodation area expressed in sqau...
# 12                    38.5  Household accommodation area expressed in sqau...
# 13                    43.7  Household accommodation area expressed in sqau...
# 14                     5.7  Household accommodation area expressed in sqau...
# 15                     2.6  Household accommodation area expressed in sqau...
# 16                     1.1  Household accommodation area expressed in sqau...
# 17                   100.0  Household accommodation area expressed in sqau...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.HouseholdByYearAndHouseholdAccommodationArea (Year, HouseholdAccommodationArea, NumberOfHouseholds, PercentageOfHouseholds, Description) values(?,?,?,?,?)", row.Year, row.HouseholdAccommodationArea, toEmptyOrInt(row.NumberOfHouseholds), toEmptyOrFloat(row.PercentageOfHouseholds), row.Description) 
cnxn.commit()
cursor.close()

# %%
df19 = xl.parse("E119e")

# %%
df19 = df19.iloc[1:12,:-2]

# %%
df19
# Out:
#    Table E119 : Median Per Capita Floor Area of Accommodation by Household Size and Year  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Year
# 4                                      Household Size
# 5                                                   1
# 6                                                   2
# 7                                                   3
# 8                                                   4
# 9                                                   5
# 10                                         6 and over
# 11                                            Overall
#
#                                            Unnamed: 1  Unnamed: 2
# 1   Median Per Capita Floor Area of Accommodation (1)         NaN
# 2                                       Square Metres         NaN
# 3                                                2016      2021.0
# 4                                                 NaN         NaN
# 5                                                  32        32.0
# 6                                                18.5        19.5
# 7                                                13.3        13.7
# 8                                                  11        11.0
# 9                                                10.4        10.2
# 10                                                  9         8.8
# 11                                                 15        16.0

# %%
result_df = pd.DataFrame()

# %%
for idx, year in enumerate(df19.iloc[2,1:]):
    for inner_idx, householdSize in enumerate(df19.iloc[4:,0]):
        new_row = [int(year), householdSize, float(df19.iloc[4+inner_idx, idx+1]), "Median individual accommodation area expressed in square meters"]
        result_df = pd.concat([result_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
result_df.columns = ["Year", "HouseholdSize", "MedianIndividualAccommodationArea", "Description"]

# %%
result_df
# Out:
#     Year HouseholdSize  MedianIndividualAccommodationArea  \
# 0   2016             1                               32.0
# 1   2016             2                               18.5
# 2   2016             3                               13.3
# 3   2016             4                               11.0
# 4   2016             5                               10.4
# 5   2016    6 and over                                9.0
# 6   2016       Overall                               15.0
# 7   2021             1                               32.0
# 8   2021             2                               19.5
# 9   2021             3                               13.7
# 10  2021             4                               11.0
# 11  2021             5                               10.2
# 12  2021    6 and over                                8.8
# 13  2021       Overall                               16.0
#
#                                           Description
# 0   Median individual accommodation area expressed...
# 1   Median individual accommodation area expressed...
# 2   Median individual accommodation area expressed...
# 3   Median individual accommodation area expressed...
# 4   Median individual accommodation area expressed...
# 5   Median individual accommodation area expressed...
# 6   Median individual accommodation area expressed...
# 7   Median individual accommodation area expressed...
# 8   Median individual accommodation area expressed...
# 9   Median individual accommodation area expressed...
# 10  Median individual accommodation area expressed...
# 11  Median individual accommodation area expressed...
# 12  Median individual accommodation area expressed...
# 13  Median individual accommodation area expressed...

# %%
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
for index, row in result_df.iterrows():
    cursor.execute("INSERT INTO Population.MedianIndividualAccommodationAreaByYearAndHouseholdSize (Year, HouseholdSize, MedianIndividualAccommodationArea, Description) values(?,?,?,?)", row.Year, row.HouseholdSize, toEmptyOrFloat(row.MedianIndividualAccommodationArea), row.Description) 
cnxn.commit()
cursor.close()
